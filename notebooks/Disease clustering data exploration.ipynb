# %%
import sys
import urllib.parse
import urllib.request
import httplib2 as http
import json
from collections import Counter

import pandas as pd
from neo4j import GraphDatabase

import mygene

from nxontology.imports import from_file
from nxontology.viz import create_similarity_graphviz

from goatools.anno.gaf_reader import GafReader
from goatools.base import download_ncbi_associations
from goatools.anno.genetogo_reader import Gene2GoReader

# %% [markdown]
# # Introduction
#
# The purpose of this notebook is to explore the types of data that can be obtain from the disease ontology knowledge graphe for the purpose of disease clustering. We obtain and explore the following types of relationships:
#
# * Disease - Gene
# * Disease - Phenotype

# %%
# Connect to disease ontology graph neo4j database

uri = "bolt://disease.ncats.io:80"
driver = GraphDatabase.driver(uri, auth=("neo4j", ""))

# %% [markdown]
# # Disease - Gene

# %% [markdown]
# ### Obtaining GARD disease to Orphanet disease-gene mappings

# %%
gard_gene_query = \
"""
MATCH p=(d:DATA)-[:PAYLOAD]->(:S_GARD)-[:R_exactMatch|:R_equivalentClass]-(m:S_MONDO) WHERE d.is_rare = TRUE
OPTIONAL MATCH q=(m)-[:R_exactMatch|:R_equivalentClass]-(:S_ORDO_ORPHANET)-[e:R_rel{name:'disease_associated_with_gene'}]->(:S_ORDO_ORPHANET)<-[:PAYLOAD]-(o:DATA)
RETURN DISTINCT d.id as `GARD_ID`,d.name as `GARD_Disease`,e.DisorderGeneAssociationType as `Disease_Gene_Association`,
o.symbol as `Gene_Symbol`,o.label as `Gene_Name`, o.hasDbXref as `Gene_Refs`
ORDER BY d.id
"""

gard_gene_res = driver.session().run(gard_gene_query)

# %%
#Convert to dict
gard_gene_data = [dict(record) for record in gard_gene_res]

#Extract the external db references
for gd in gard_gene_data:
    if gd['Gene_Refs'] is not None:
        for ref_id in gd['Gene_Refs']:
            ref = ref_id.split(':')
            gd[ref[0]] = ref[1]

# %%
gard_gene_data
# Out:
# [{'GARD_ID': 1,
#   'GARD_Disease': 'GRACILE syndrome',
#   'Disease_Gene_Association': 'Disease-causing germline mutation(s) in',
#   'Gene_Symbol': 'BCS1L',
#   'Gene_Name': 'BCS1 homolog, ubiquinol-cytochrome c reductase complex chaperone',
#   'Gene_Refs': ['OMIM:603647',
#    'Ensembl:ENSG00000074582',
#    'Genatlas:BCS1L',
#    'SwissProt:Q9Y276',
#    'HGNC:1020',
#    'Reactome:Q9Y276'],
#   'OMIM': '603647',
#   'Ensembl': 'ENSG00000074582',
#   'Genatlas': 'BCS1L',
#   'SwissProt': 'Q9Y276',
#   'HGNC': '1020',
#   'Reactome': 'Q9Y276'},
#  {'GARD_ID': 3,
#   'GARD_Disease': 'Ablepharon macrostomia syndrome',
#   'Disease_Gene_Association': 'Disease-causing germline mutation(s) in',
#   'Gene_Symbol': 'TWIST2',
#   'Gene_Name': 'twist family bHLH transcription factor 2',
#   'Gene_Refs': ['Ensembl:ENSG00000233608',
#    'OMIM:607556',
#    'Reactome:Q8WVJ9',
#    'Genatlas:TWIST2',
#    'SwissProt:Q8WVJ9',
#    'HGNC:20670'],
#   'Ensembl': 'ENSG00000233608',
#   'OMIM': '607556',
#   'Reactome': 'Q8WVJ9',
#   'Genatlas': 'TWIST2',
#   'SwissProt': 'Q8WVJ9',
#   'HGNC': '20670'},
#  {'GARD_ID': 4,
#   'GARD_Disease': 'Acanthocheilonemiasis',
#   'Disease_Gene_Association': None,
#   'Gene_Symbol': None,
#   'Gene_Name': None,
#   'Gene_Refs': None},
#  {'GARD_ID': 5,
#   'GARD_Disease': 'Abetalipoproteinemia',
#   'Disease_Gene_Association': 'Disease-causing germline mutation(s) in',
#   'Gene_Symbol': 'MTTP',
#   'Gene_Name': 'microsomal triglyceride transfer protein',
#   'Gene_Refs': ['Ensembl:ENSG00000138823',
#    'Genatlas:MTTP',
#    'Reactome:P55157',
#    'HGNC:7467',
#    'OMIM:157147',
#    'SwissProt:P55157'],
#   'Ensembl': 'ENSG00000138823',
#   'Genatlas': 'MTTP',
#   'Reactome': 'P55157',
#   'HGNC': '7467',
#   'OMIM': '157147',
#   'SwissProt': 'P55157'},
#  {'GARD_ID': 6,
#   'GARD_Disease': 'Acromesomelic dysplasia',
#   'Disease_Gene_Association': None,
#   'Gene_Symbol': None,
#   'Gene_Name': None,
#   'Gene_Refs': None},
#  {'GARD_ID': 7,
#   'GARD_Disease': 'Acromicric dysplasia',
#   'Disease_Gene_Association': 'Disease-causing germline mutation(s) in',
#   'Gene_Symbol': 'FBN1',
#   'Gene_Name': 'fibrillin 1',
#   'Gene_Refs': ['Reactome:P35555',
#    'Genatlas:FBN1',
#    'OMIM:134797',
#    'Ensembl:ENSG00000166147',
#    'HGNC:3603',
#    'SwissProt:P35555'],
#   'Reactome': 'P35555',
#   'Genatlas': 'FBN1',
#   'OMIM': '134797',
#   'Ensembl': 'ENSG00000166147',
#   'HGNC': '3603',
#   'SwissProt': 'P35555'},
#  {'GARD_ID': 7,
#   'GARD_Disease': 'Acromicric dysplasia',
#   'Disease_Gene_Association': 'Disease-causing germline mutation(s) in',
#   'Gene_Symbol': 'LTBP3',
#   'Gene_Name': 'latent transforming growth factor beta binding protein 3',
#   'Gene_Refs': ['Reactome:Q9NS15',
#    'Genatlas:LTBP3',
#    'Ensembl:ENSG00000168056',
#    'OMIM:602090',
#    'HGNC:6716',
#    'SwissProt:Q9NS15'],
#   'Reactome': 'Q9NS15',
#   'Genatlas': 'LTBP3',
#   'Ensembl': 'ENSG00000168056',
#   'OMIM': '602090',
#   'HGNC': '6716',
#   'SwissProt': 'Q9NS15'},
#  {'GARD_ID': 8,
#   'GARD_Disease': 'Agnosia',
#   'Disease_Gene_Association': None,
#   'Gene_Symbol': None,
#   'Gene_Name': None,
#   'Gene_Refs': None},
#  {'GARD_ID': 11,
#   'GARD_Disease': 'Alternating hemiplegia of childhood',
#   'Disease_Gene_Association': 'Candidate gene tested in',
#   'Gene_Symbol': 'CACNA1A',
#   'Gene_Name': 'calcium voltage-gated channel subunit alpha1 A',
#   'Gene_Refs': ['IUPHAR:532',
#    'Reactome:O00555',
#    'OMIM:601011',
#    'Genatlas:CACNA1A',
#    'Ensembl:ENSG00000141837',
#    'SwissProt:O00555',
#    'HGNC:1388'],
#   'IUPHAR': '532',
#   'Reactome': 'O00555',
#   'OMIM': '601011',
#   'Genatlas': 'CACNA1A',
#   'Ensembl': 'ENSG00000141837',
#   'SwissProt': 'O00555',
#   'HGNC': '1388'},
#  {'GARD_ID': 11,
#   'GARD_Disease': 'Alternating hemiplegia of childhood',
#   'Disease_Gene_Association': 'Disease-causing germline mutation(s) in',
#   'Gene_Symbol': 'ATP1A2',
#   'Gene_Name': 'ATPase Na+/K+ transporting subunit alpha 2',
#   'Gene_Refs': ['Reactome:P50993',
#    'OMIM:182340',
#    'Genatlas:ATP1A2',
#    'SwissProt:P50993',
#    'HGNC:800',
#    'Ensembl:ENSG00000018625'],
#   'Reactome': 'P50993',
#   'OMIM': '182340',
#   'Genatlas': 'ATP1A2',
#   'SwissProt': 'P50993',
#   'HGNC': '800',
#   'Ensembl': 'ENSG00000018625'},
#  {'GARD_ID': 11,
#   'GARD_Disease': 'Alternating hemiplegia of childhood',
#   'Disease_Gene_Association': 'Disease-causing germline mutation(s) in',
#   'Gene_Symbol': 'ATP1A3',
#   'Gene_Name': 'ATPase Na+/K+ transporting subunit alpha 3',
#   'Gene_Refs': ['SwissProt:P13637',
#    'HGNC:801',
#    'Reactome:P13637',
#    'Genatlas:ATP1A3',
#    'Ensembl:ENSG00000105409',
#    'OMIM:182350'],
#   'SwissProt': 'P13637',
#   'HGNC': '801',
#   'Reactome': 'P13637',
#   'Genatlas': 'ATP1A3',
#   'Ensembl': 'ENSG00000105409',
#   'OMIM': '182350'},
#  {'GARD_ID': 11,
#   'GARD_Disease': 'Alternating hemiplegia of childhood',
#   'Disease_Gene_Association': 'Candidate gene tested in',
#   'Gene_Symbol': 'SLC1A3',
#   'Gene_Name': 'solute carrier family 1 member 3',
#   'Gene_Refs': ['OMIM:600111',
#    'Ensembl:ENSG00000079215',
#    'SwissProt:P43003',
#    'HGNC:10941',
#    'Reactome:P43003',
#    'Genatlas:SLC1A3'],
#   'OMIM': '600111',
#   'Ensembl': 'ENSG00000079215',
#   'SwissProt': 'P43003',
#   'HGNC': '10941',
#   'Reactome': 'P43003',
#   'Genatlas': 'SLC1A3'},
#  {'GARD_ID': 12,
#   'GARD_Disease': 'Hypersensitivity pneumonitis',
#   'Disease_Gene_Association': None,
#   'Gene_Symbol': None,
#   'Gene_Name': None,
#   'Gene_Refs': None},
#  {'GARD_ID': 13,
#   'GARD_Disease': 'Gillespie syndrome',
#   'Disease_Gene_Association': 'Disease-causing germline mutation(s) in',
#   'Gene_Symbol': 'ITPR1',
#   'Gene_Name': 'inositol 1,4,5-trisphosphate receptor type 1',
#   'Gene_Refs': ['Ensembl:ENSG00000150995',
#    'Reactome:Q14643',
#    'Genatlas:ITPR1',
#    'SwissProt:Q14643',
#    'HGNC:6180',
#    'OMIM:147265'],
#   'Ensembl': 'ENSG00000150995',
#   'Reactome': 'Q14643',
#   'Genatlas': 'ITPR1',
#   'SwissProt': 'Q14643',
#   'HGNC': '6180',
#   'OMIM': '147265'},
#  {'GARD_ID': 13,
#   'GARD_Disease': 'Gillespie syndrome',
#   'Disease_Gene_Association': 'Disease-causing germline mutation(s) in',
#   'Gene_Symbol': 'PAX6',
#   'Gene_Name': 'paired box 6',
#   'Gene_Refs': ['Reactome:P26367',
#    'Genatlas:PAX6',
#    'OMIM:607108',
#    'Ensembl:ENSG00000007372',
#    'SwissProt:P26367',
#    'HGNC:8620'],
#   'Reactome': 'P26367',
#   'Genatlas': 'PAX6',
#   'OMIM': '607108',
#   'Ensembl': 'ENSG00000007372',
#   'SwissProt': 'P26367',
#   'HGNC': '8620'},
#  {'GARD_ID': 16,
#   'GARD_Disease': 'Oculomotor apraxia Cogan type',
#   'Disease_Gene_Association': None,
#   'Gene_Symbol': None,
#   'Gene_Name': None,
#   'Gene_Refs': None},
#  {'GARD_ID': 17,
#   'GARD_Disease': 'Arachnoid cysts',
#   'Disease_Gene_Association': None,
#   'Gene_Symbol': None,
#   'Gene_Name': None,
#   'Gene_Refs': None},
#  {'GARD_ID': 22,
#   'GARD_Disease': 'Bjornstad syndrome',
#   'Disease_Gene_Association': 'Disease-causing germline mutation(s) in',
#   'Gene_Symbol': 'BCS1L',
#   'Gene_Name': 'BCS1 homolog, ubiquinol-cytochrome c reductase complex chaperone',
#   'Gene_Refs': ['OMIM:603647',
#    'Ensembl:ENSG00000074582',
#    'Genatlas:BCS1L',
#    'SwissProt:Q9Y276',
#    'HGNC:1020',
#    'Reactome:Q9Y276'],
#   'OMIM': '603647',
#   'Ensembl': 'ENSG00000074582',
#   'Genatlas': 'BCS1L',
#   'SwissProt': 'Q9Y276',
#   'HGNC': '1020',
#   'Reactome': 'Q9Y276'},
#  {'GARD_ID': 26,
#   'GARD_Disease': 'Cat eye syndrome',
#   'Disease_Gene_Association': None,
#   'Gene_Symbol': None,
#   'Gene_Name': None,
#   'Gene_Refs': None},
#  {'GARD_ID': 27,
#   'GARD_Disease': 'Cat scratch disease',
#   'Disease_Gene_Association': None,
#   'Gene_Symbol': None,
#   'Gene_Name': None,
#   'Gene_Refs': None},
#  {'GARD_ID': 28,
#   'GARD_Disease': 'Catel Manzke syndrome',
#   'Disease_Gene_Association': 'Disease-causing germline mutation(s) in',
#   'Gene_Symbol': 'TGDS',
#   'Gene_Name': 'TDP-glucose 4,6-dehydratase',
#   'Gene_Refs': ['Ensembl:ENSG00000088451',
#    'SwissProt:O95455',
#    'Genatlas:TGDS',
#    'OMIM:616146',
#    'HGNC:20324'],
#   'Ensembl': 'ENSG00000088451',
#   'SwissProt': 'O95455',
#   'Genatlas': 'TGDS',
#   'OMIM': '616146',
#   'HGNC': '20324'},
#  {'GARD_ID': 29,
#   'GARD_Disease': 'CHARGE syndrome',
#   'Disease_Gene_Association': 'Candidate gene tested in',
#   'Gene_Symbol': 'SEMA3E',
#   'Gene_Name': 'semaphorin 3E',
#   'Gene_Refs': ['OMIM:608166',
#    'Reactome:O15041',
#    'Genatlas:SEMA3E',
#    'HGNC:10727',
#    'Ensembl:ENSG00000170381',
#    'SwissProt:O15041'],
#   'OMIM': '608166',
#   'Reactome': 'O15041',
#   'Genatlas': 'SEMA3E',
#   'HGNC': '10727',
#   'Ensembl': 'ENSG00000170381',
#   'SwissProt': 'O15041'},
#  {'GARD_ID': 29,
#   'GARD_Disease': 'CHARGE syndrome',
#   'Disease_Gene_Association': 'Disease-causing germline mutation(s) in',
#   'Gene_Symbol': 'CHD7',
#   'Gene_Name': 'chromodomain helicase DNA binding protein 7',
#   'Gene_Refs': ['OMIM:608892',
#    'Ensembl:ENSG00000171316',
#    'SwissProt:Q9P2D1',
#    'Genatlas:CHD7',
#    'HGNC:20626'],
#   'OMIM': '608892',
#   'Ensembl': 'ENSG00000171316',
#   'SwissProt': 'Q9P2D1',
#   'Genatlas': 'CHD7',
#   'HGNC': '20626'},
#  {'GARD_ID': 30,
#   'GARD_Disease': 'Cholecystitis',
#   'Disease_Gene_Association': None,
#   'Gene_Symbol': None,
#   'Gene_Name': None,
#   'Gene_Refs': None},
#  {'GARD_ID': 31,
#   'GARD_Disease': 'Serpiginous choroiditis',
#   'Disease_Gene_Association': None,
#   'Gene_Symbol': None,
#   'Gene_Name': None,
#   'Gene_Refs': None},
#  {'GARD_ID': 35,
#   'GARD_Disease': 'Chromosome 18p tetrasomy',
#   'Disease_Gene_Association': None,
#   'Gene_Symbol': None,
#   'Gene_Name': None,
#   'Gene_Refs': None},
#  {'GARD_ID': 37,
#   'GARD_Disease': 'Partial deletion of the short arm of chromosome 3',
#   'Disease_Gene_Association': None,
#   'Gene_Symbol': None,
#   'Gene_Name': None,
#   'Gene_Refs': None},
#  {'GARD_ID': 39,
#   'GARD_Disease': 'WT limb blood syndrome',
#   'Disease_Gene_Association': None,
#   'Gene_Symbol': None,
#   'Gene_Name': None,
#   'Gene_Refs': None},
#  {'GARD_ID': 42,
#   'GARD_Disease': 'Tetrasomy 9p',
#   'Disease_Gene_Association': None,
#   'Gene_Symbol': None,
#   'Gene_Name': None,
#   'Gene_Refs': None},
#  {'GARD_ID': 43,
#   'GARD_Disease': 'Mosaic trisomy 9',
#   'Disease_Gene_Association': None,
#   'Gene_Symbol': None,
#   'Gene_Name': None,
#   'Gene_Refs': None},
#  {'GARD_ID': 44,
#   'GARD_Disease': 'Haim-Munk syndrome',
#   'Disease_Gene_Association': 'Disease-causing germline mutation(s) in',
#   'Gene_Symbol': 'CTSC',
#   'Gene_Name': 'cathepsin C',
#   'Gene_Refs': ['SwissProt:P53634',
#    'HGNC:2528',
#    'Ensembl:ENSG00000109861',
#    'IUPHAR:2344',
#    'Reactome:P53634',
#    'Genatlas:CTSC',
#    'OMIM:602365'],
#   'SwissProt': 'P53634',
#   'HGNC': '2528',
#   'Ensembl': 'ENSG00000109861',
#   'IUPHAR': '2344',
#   'Reactome': 'P53634',
#   'Genatlas': 'CTSC',
#   'OMIM': '602365'},
#  {'GARD_ID': 45,
#   'GARD_Disease': 'Congenital varicella syndrome',
#   'Disease_Gene_Association': None,
#   'Gene_Symbol': None,
#   'Gene_Name': None,
#   'Gene_Refs': None},
#  {'GARD_ID': 46,
#   'GARD_Disease': 'Corticobasal degeneration',
#   'Disease_Gene_Association': None,
#   'Gene_Symbol': None,
#   'Gene_Name': None,
#   'Gene_Refs': None},
#  {'GARD_ID': 47,
#   'GARD_Disease': 'Crigler Najjar syndrome, type 1',
#   'Disease_Gene_Association': 'Disease-causing germline mutation(s) (loss of function) in',
#   'Gene_Symbol': 'UGT1A1',
#   'Gene_Name': 'UDP glucuronosyltransferase family 1 member A1',
#   'Gene_Refs': ['HGNC:12530',
#    'Ensembl:ENSG00000241635',
#    'Genatlas:UGT1A1',
#    'OMIM:191740',
#    'Reactome:P22309',
#    'SwissProt:P22309'],
#   'HGNC': '12530',
#   'Ensembl': 'ENSG00000241635',
#   'Genatlas': 'UGT1A1',
#   'OMIM': '191740',
#   'Reactome': 'P22309',
#   'SwissProt': 'P22309'},
#  {'GARD_ID': 48,
#   'GARD_Disease': 'Cytochrome c oxidase deficiency',
#   'Disease_Gene_Association': 'Disease-causing germline mutation(s) in',
#   'Gene_Symbol': 'COX10',
#   'Gene_Name': 'cytochrome c oxidase assembly factor heme A:farnesyltransferase COX10',
#   'Gene_Refs': ['Ensembl:ENSG00000006695',
#    'Reactome:Q12887',
#    'HGNC:2260',
#    'OMIM:602125',
#    'SwissProt:Q12887',
#    'Genatlas:COX10'],
#   'Ensembl': 'ENSG00000006695',
#   'Reactome': 'Q12887',
#   'HGNC': '2260',
#   'OMIM': '602125',
#   'SwissProt': 'Q12887',
#   'Genatlas': 'COX10'},
#  {'GARD_ID': 48,
#   'GARD_Disease': 'Cytochrome c oxidase deficiency',
#   'Disease_Gene_Association': 'Disease-causing germline mutation(s) in',
#   'Gene_Symbol': 'MT-CO1',
#   'Gene_Name': 'mitochondrially encoded cytochrome c oxidase I',
#   'Gene_Refs': ['Genatlas:MT-CO1',
#    'OMIM:516030',
#    'HGNC:7419',
#    'Reactome:P00395',
#    'Ensembl:ENSG00000198804',
#    'SwissProt:P00395'],
#   'Genatlas': 'MT-CO1',
#   'OMIM': '516030',
#   'HGNC': '7419',
#   'Reactome': 'P00395',
#   'Ensembl': 'ENSG00000198804',
#   'SwissProt': 'P00395'},
#  {'GARD_ID': 48,
#   'GARD_Disease': 'Cytochrome c oxidase deficiency',
#   'Disease_Gene_Association': 'Disease-causing germline mutation(s) (loss of function) in',
#   'Gene_Symbol': 'MT-CO2',
#   'Gene_Name': 'mitochondrially encoded cytochrome c oxidase II',
#   'Gene_Refs': ['SwissProt:P00403',
#    'Reactome:P00403',
#    'OMIM:516040',
#    'Genatlas:MT-CO2',
#    'HGNC:7421',
#    'Ensembl:ENSG00000198712'],
#   'SwissProt': 'P00403',
#   'Reactome': 'P00403',
#   'OMIM': '516040',
#   'Genatlas': 'MT-CO2',
#   'HGNC': '7421',
#   'Ensembl': 'ENSG00000198712'},
#  {'GARD_ID': 48,
#   'GARD_Disease': 'Cytochrome c oxidase deficiency',
#   'Disease_Gene_Association': 'Disease-causing germline mutation(s) in',
#   'Gene_Symbol': 'MT-CO3',
#   'Gene_Name': 'mitochondrially encoded cytochrome c oxidase III',
#   'Gene_Refs': ['Genatlas:MT-CO3',
#    'OMIM:516050',
#    'HGNC:7422',
#    'Ensembl:ENSG00000198938',
#    'SwissProt:P00414',
#    'Reactome:P00414'],
#   'Genatlas': 'MT-CO3',
#   'OMIM': '516050',
#   'HGNC': '7422',
#   'Ensembl': 'ENSG00000198938',
#   'SwissProt': 'P00414',
#   'Reactome': 'P00414'},
#  {'GARD_ID': 48,
#   'GARD_Disease': 'Cytochrome c oxidase deficiency',
#   'Disease_Gene_Association': 'Disease-causing germline mutation(s) in',
#   'Gene_Symbol': 'COX6B1',
#   'Gene_Name': 'cytochrome c oxidase subunit 6B1',
#   'Gene_Refs': ['Ensembl:ENSG00000126267',
#    'OMIM:124089',
#    'Genatlas:COX6B1',
#    'Reactome:P14854',
#    'HGNC:2280',
#    'SwissProt:P14854'],
#   'Ensembl': 'ENSG00000126267',
#   'OMIM': '124089',
#   'Genatlas': 'COX6B1',
#   'Reactome': 'P14854',
#   'HGNC': '2280',
#   'SwissProt': 'P14854'},
#  {'GARD_ID': 48,
#   'GARD_Disease': 'Cytochrome c oxidase deficiency',
#   'Disease_Gene_Association': 'Disease-causing germline mutation(s) in',
#   'Gene_Symbol': 'COX14',
#   'Gene_Name': 'cytochrome c oxidase assembly factor COX14',
#   'Gene_Refs': ['Genatlas:C12orf62',
#    'Reactome:Q96I36',
#    'SwissProt:Q96I36',
#    'OMIM:614478',
#    'Ensembl:ENSG00000178449',
#    'HGNC:28216'],
#   'Genatlas': 'C12orf62',
#   'Reactome': 'Q96I36',
#   'SwissProt': 'Q96I36',
#   'OMIM': '614478',
#   'Ensembl': 'ENSG00000178449',
#   'HGNC': '28216'},
#  {'GARD_ID': 48,
#   'GARD_Disease': 'Cytochrome c oxidase deficiency',
#   'Disease_Gene_Association': 'Disease-causing germline mutation(s) in',
#   'Gene_Symbol': 'COX20',
#   'Gene_Name': 'cytochrome c oxidase assembly factor COX20',
#   'Gene_Refs': ['Reactome:Q5RI15',
#    'SwissProt:Q5RI15',
#    'Ensembl:ENSG00000203667',
#    'Genatlas:COX20',
#    'HGNC:26970',
#    'OMIM:614698'],
#   'Reactome': 'Q5RI15',
#   'SwissProt': 'Q5RI15',
#   'Ensembl': 'ENSG00000203667',
#   'Genatlas': 'COX20',
#   'HGNC': '26970',
#   'OMIM': '614698'},
#  {'GARD_ID': 48,
#   'GARD_Disease': 'Cytochrome c oxidase deficiency',
#   'Disease_Gene_Association': 'Disease-causing germline mutation(s) in',
#   'Gene_Symbol': 'COA3',
#   'Gene_Name': 'cytochrome c oxidase assembly factor 3',
#   'Gene_Refs': ['HGNC:24990',
#    'Genatlas:COA3',
#    'OMIM:614775',
#    'Ensembl:ENSG00000183978',
#    'SwissProt:Q9Y2R0'],
#   'HGNC': '24990',
#   'Genatlas': 'COA3',
#   'OMIM': '614775',
#   'Ensembl': 'ENSG00000183978',
#   'SwissProt': 'Q9Y2R0'},
#  {'GARD_ID': 48,
#   'GARD_Disease': 'Cytochrome c oxidase deficiency',
#   'Disease_Gene_Association': 'Disease-causing germline mutation(s) (loss of function) in',
#   'Gene_Symbol': 'COX8A',
#   'Gene_Name': 'cytochrome c oxidase subunit 8A',
#   'Gene_Refs': ['Ensembl:ENSG00000176340',
#    'SwissProt:P10176',
#    'Reactome:P10176',
#    'HGNC:2294',
#    'OMIM:123870',
#    'Genatlas:COX8A'],
#   'Ensembl': 'ENSG00000176340',
#   'SwissProt': 'P10176',
#   'Reactome': 'P10176',
#   'HGNC': '2294',
#   'OMIM': '123870',
#   'Genatlas': 'COX8A'},
#  {'GARD_ID': 48,
#   'GARD_Disease': 'Cytochrome c oxidase deficiency',
#   'Disease_Gene_Association': 'Disease-causing germline mutation(s) in',
#   'Gene_Symbol': 'PET117',
#   'Gene_Name': 'PET117 cytochrome c oxidase chaperone',
#   'Gene_Refs': ['OMIM:614771',
#    'Ensembl:ENSG00000232838',
#    'HGNC:40045',
#    'SwissProt:Q6UWS5'],
#   'OMIM': '614771',
#   'Ensembl': 'ENSG00000232838',
#   'HGNC': '40045',
#   'SwissProt': 'Q6UWS5'},
#  {'GARD_ID': 48,
#   'GARD_Disease': 'Cytochrome c oxidase deficiency',
#   'Disease_Gene_Association': 'Disease-causing germline mutation(s) (loss of function) in',
#   'Gene_Symbol': 'COX5A',
#   'Gene_Name': 'cytochrome c oxidase subunit 5A',
#   'Gene_Refs': ['HGNC:2267',
#    'Genatlas:COX5A',
#    'OMIM:603773',
#    'Reactome:P20674',
#    'Ensembl:ENSG00000178741',
#    'SwissProt:P20674'],
#   'HGNC': '2267',
#   'Genatlas': 'COX5A',
#   'OMIM': '603773',
#   'Reactome': 'P20674',
#   'Ensembl': 'ENSG00000178741',
#   'SwissProt': 'P20674'},
#  {'GARD_ID': 49,
#   'GARD_Disease': 'De Barsy syndrome',
#   'Disease_Gene_Association': None,
#   'Gene_Symbol': None,
#   'Gene_Name': None,
#   'Gene_Refs': None},
#  {'GARD_ID': 54,
#   'GARD_Disease': 'Duodenal atresia',
#   'Disease_Gene_Association': None,
#   'Gene_Symbol': None,
#   'Gene_Name': None,
#   'Gene_Refs': None},
#  {'GARD_ID': 59,
#   'GARD_Disease': 'Spinocerebellar ataxia 34',
#   'Disease_Gene_Association': 'Disease-causing germline mutation(s) in',
#   'Gene_Symbol': 'ELOVL4',
#   'Gene_Name': 'ELOVL fatty acid elongase 4',
#   'Gene_Refs': ['Reactome:Q9GZR5',
#    'OMIM:605512',
#    'HGNC:14415',
#    'Genatlas:ELOVL4',
#    'Ensembl:ENSG00000118402',
#    'SwissProt:Q9GZR5'],
#   'Reactome': 'Q9GZR5',
#   'OMIM': '605512',
#   'HGNC': '14415',
#   'Genatlas': 'ELOVL4',
#   'Ensembl': 'ENSG00000118402',
#   'SwissProt': 'Q9GZR5'},
#  {'GARD_ID': 60,
#   'GARD_Disease': 'Iridocorneal endothelial syndrome',
#   'Disease_Gene_Association': None,
#   'Gene_Symbol': None,
#   'Gene_Name': None,
#   'Gene_Refs': None},
#  {'GARD_ID': 61,
#   'GARD_Disease': 'Femoral facial syndrome',
#   'Disease_Gene_Association': None,
#   'Gene_Symbol': None,
#   'Gene_Name': None,
#   'Gene_Refs': None},
#  {'GARD_ID': 62,
#   'GARD_Disease': 'Filippi syndrome',
#   'Disease_Gene_Association': 'Disease-causing germline mutation(s) (loss of function) in',
#   'Gene_Symbol': 'CKAP2L',
#   'Gene_Name': 'cytoskeleton associated protein 2 like',
#   'Gene_Refs': ['SwissProt:Q8IYA6',
#    'OMIM:616174',
#    'Ensembl:ENSG00000169607',
#    'Genatlas:CKAP2L',
#    'HGNC:26877'],
#   'SwissProt': 'Q8IYA6',
#   'OMIM': '616174',
#   'Ensembl': 'ENSG00000169607',
#   'Genatlas': 'CKAP2L',
#   'HGNC': '26877'},
#  {'GARD_ID': 64,
#   'GARD_Disease': 'Fountain syndrome',
#   'Disease_Gene_Association': None,
#   'Gene_Symbol': None,
#   'Gene_Name': None,
#   'Gene_Refs': None},
#  {'GARD_ID': 65,
#   'GARD_Disease': 'Galloway-Mowat syndrome',
#   'Disease_Gene_Association': 'Disease-causing germline mutation(s) in',
#   'Gene_Symbol': 'OSGEP',
#   'Gene_Name': 'O-sialoglycoprotein endopeptidase',
#   'Gene_Refs': ['HGNC:18028',
#    'Reactome:Q9NPF4',
#    'SwissProt:Q9NPF4',
#    'Genatlas:OSGEP',
#    'OMIM:610107',
#    'Ensembl:ENSG00000092094'],
#   'HGNC': '18028',
#   'Reactome': 'Q9NPF4',
#   'SwissProt': 'Q9NPF4',
#   'Genatlas': 'OSGEP',
#   'OMIM': '610107',
#   'Ensembl': 'ENSG00000092094'},
#  {'GARD_ID': 65,
#   'GARD_Disease': 'Galloway-Mowat syndrome',
#   'Disease_Gene_Association': 'Disease-causing germline mutation(s) in',
#   'Gene_Symbol': 'TP53RK',
#   'Gene_Name': 'TP53 regulating kinase',
#   'Gene_Refs': ['Genatlas:TP53RK',
#    'IUPHAR:2248',
#    'SwissProt:Q96S44',
#    'Reactome:Q96S44',
#    'Ensembl:ENSG00000172315',
#    'OMIM:608679',
#    'HGNC:16197'],
#   'Genatlas': 'TP53RK',
#   'IUPHAR': '2248',
#   'SwissProt': 'Q96S44',
#   'Reactome': 'Q96S44',
#   'Ensembl': 'ENSG00000172315',
#   'OMIM': '608679',
#   'HGNC': '16197'},
#  {'GARD_ID': 65,
#   'GARD_Disease': 'Galloway-Mowat syndrome',
#   'Disease_Gene_Association': 'Disease-causing germline mutation(s) (loss of function) in',
#   'Gene_Symbol': 'WDR73',
#   'Gene_Name': 'WD repeat domain 73',
#   'Gene_Refs': ['Genatlas:WDR73',
#    'Ensembl:ENSG00000177082',
#    'HGNC:25928',
#    'OMIM:616144',
#    'SwissProt:Q6P4I2'],
#   'Genatlas': 'WDR73',
#   'Ensembl': 'ENSG00000177082',
#   'HGNC': '25928',
#   'OMIM': '616144',
#   'SwissProt': 'Q6P4I2'},
#  {'GARD_ID': 65,
#   'GARD_Disease': 'Galloway-Mowat syndrome',
#   'Disease_Gene_Association': 'Disease-causing germline mutation(s) in',
#   'Gene_Symbol': 'NUP107',
#   'Gene_Name': 'nucleoporin 107',
#   'Gene_Refs': ['HGNC:29914',
#    'SwissProt:P57740',
#    'Genatlas:NUP107',
#    'OMIM:607617',
#    'Ensembl:ENSG00000111581',
#    'Reactome:P57740'],
#   'HGNC': '29914',
#   'SwissProt': 'P57740',
#   'Genatlas': 'NUP107',
#   'OMIM': '607617',
#   'Ensembl': 'ENSG00000111581',
#   'Reactome': 'P57740'},
#  {'GARD_ID': 65,
#   'GARD_Disease': 'Galloway-Mowat syndrome',
#   'Disease_Gene_Association': 'Disease-causing germline mutation(s) in',
#   'Gene_Symbol': 'TPRKB',
#   'Gene_Name': 'TP53RK binding protein',
#   'Gene_Refs': ['SwissProt:Q9Y3C4',
#    'HGNC:24259',
#    'OMIM:608680',
#    'Reactome:Q9Y3C4',
#    'Genatlas:TPRKB',
#    'Ensembl:ENSG00000144034'],
#   'SwissProt': 'Q9Y3C4',
#   'HGNC': '24259',
#   'OMIM': '608680',
#   'Reactome': 'Q9Y3C4',
#   'Genatlas': 'TPRKB',
#   'Ensembl': 'ENSG00000144034'},
#  {'GARD_ID': 65,
#   'GARD_Disease': 'Galloway-Mowat syndrome',
#   'Disease_Gene_Association': 'Disease-causing germline mutation(s) in',
#   'Gene_Symbol': 'LAGE3',
#   'Gene_Name': 'L antigen family member 3',
#   'Gene_Refs': ['OMIM:300060',
#    'SwissProt:Q14657',
#    'HGNC:26058',
#    'Genatlas:LAGE3',
#    'Ensembl:ENSG00000196976',
#    'Reactome:Q14657'],
#   'OMIM': '300060',
#   'SwissProt': 'Q14657',
#   'HGNC': '26058',
#   'Genatlas': 'LAGE3',
#   'Ensembl': 'ENSG00000196976',
#   'Reactome': 'Q14657'},
#  {'GARD_ID': 65,
#   'GARD_Disease': 'Galloway-Mowat syndrome',
#   'Disease_Gene_Association': 'Disease-causing germline mutation(s) in',
#   'Gene_Symbol': 'WDR4',
#   'Gene_Name': 'WD repeat domain 4',
#   'Gene_Refs': ['OMIM:605924',
#    'Reactome:P57081',
#    'Ensembl:ENSG00000160193',
#    'HGNC:12756',
#    'SwissProt:P57081',
#    'Genatlas:WDR4'],
#   'OMIM': '605924',
#   'Reactome': 'P57081',
#   'Ensembl': 'ENSG00000160193',
#   'HGNC': '12756',
#   'SwissProt': 'P57081',
#   'Genatlas': 'WDR4'},
#  {'GARD_ID': 65,
#   'GARD_Disease': 'Galloway-Mowat syndrome',
#   'Disease_Gene_Association': 'Disease-causing germline mutation(s) (loss of function) in',
#   'Gene_Symbol': 'NUP133',
#   'Gene_Name': 'nucleoporin 133',
#   'Gene_Refs': ['HGNC:18016',
#    'SwissProt:Q8WUM0',
#    'Ensembl:ENSG00000069248',
#    'Reactome:Q8WUM0',
#    'OMIM:607613'],
#   'HGNC': '18016',
#   'SwissProt': 'Q8WUM0',
#   'Ensembl': 'ENSG00000069248',
#   'Reactome': 'Q8WUM0',
#   'OMIM': '607613'},
#  {'GARD_ID': 66,
#   'GARD_Disease': 'Gorlin Chaudhry Moss syndrome',
#   'Disease_Gene_Association': 'Disease-causing germline mutation(s) in',
#   'Gene_Symbol': 'SLC25A24',
#   'Gene_Name': 'solute carrier family 25 member 24',
#   'Gene_Refs': ['SwissProt:Q6NUK1',
#    'Genatlas:SLC25A24',
#    'HGNC:20662',
#    'OMIM:608744',
#    'Ensembl:ENSG00000085491'],
#   'SwissProt': 'Q6NUK1',
#   'Genatlas': 'SLC25A24',
#   'HGNC': '20662',
#   'OMIM': '608744',
#   'Ensembl': 'ENSG00000085491'},
#  {'GARD_ID': 68,
#   'GARD_Disease': 'Hanhart syndrome',
#   'Disease_Gene_Association': None,
#   'Gene_Symbol': None,
#   'Gene_Name': None,
#   'Gene_Refs': None},
#  {'GARD_ID': 69,
#   'GARD_Disease': 'Hantavirus pulmonary syndrome',
#   'Disease_Gene_Association': None,
#   'Gene_Symbol': None,
#   'Gene_Name': None,
#   'Gene_Refs': None},
#  {'GARD_ID': 70,
#   'GARD_Disease': 'Hemangioma thrombocytopenia syndrome',
#   'Disease_Gene_Association': None,
#   'Gene_Symbol': None,
#   'Gene_Name': None,
#   'Gene_Refs': None},
#  {'GARD_ID': 71,
#   'GARD_Disease': 'Human granulocytic ehrlichiosis',
#   'Disease_Gene_Association': None,
#   'Gene_Symbol': None,
#   'Gene_Name': None,
#   'Gene_Refs': None},
#  {'GARD_ID': 72,
#   'GARD_Disease': 'Human monocytic ehrlichiosis',
#   'Disease_Gene_Association': None,
#   'Gene_Symbol': None,
#   'Gene_Name': None,
#   'Gene_Refs': None},
#  {'GARD_ID': 73,
#   'GARD_Disease': 'Immunodeficiency with hyper IgM type 1',
#   'Disease_Gene_Association': 'Disease-causing germline mutation(s) in',
#   'Gene_Symbol': 'CD40LG',
#   'Gene_Name': 'CD40 ligand',
#   'Gene_Refs': ['OMIM:300386',
#    'SwissProt:P29965',
#    'Genatlas:CD40LG',
#    'HGNC:11935',
#    'Reactome:P29965',
#    'Ensembl:ENSG00000102245'],
#   'OMIM': '300386',
#   'SwissProt': 'P29965',
#   'Genatlas': 'CD40LG',
#   'HGNC': '11935',
#   'Reactome': 'P29965',
#   'Ensembl': 'ENSG00000102245'},
#  {'GARD_ID': 76,
#   'GARD_Disease': 'Hypohidrotic ectodermal dysplasia',
#   'Disease_Gene_Association': None,
#   'Gene_Symbol': None,
#   'Gene_Name': None,
#   'Gene_Refs': None},
#  {'GARD_ID': 79,
#   'GARD_Disease': 'Jansen type metaphyseal chondrodysplasia',
#   'Disease_Gene_Association': 'Disease-causing germline mutation(s) (gain of function) in',
#   'Gene_Symbol': 'PTH1R',
#   'Gene_Name': 'parathyroid hormone 1 receptor',
#   'Gene_Refs': ['OMIM:168468',
#    'Reactome:Q03431',
#    'Ensembl:ENSG00000160801',
#    'SwissProt:Q03431',
#    'HGNC:9608',
#    'Genatlas:PTH1R',
#    'IUPHAR:331'],
#   'OMIM': '168468',
#   'Reactome': 'Q03431',
#   'Ensembl': 'ENSG00000160801',
#   'SwissProt': 'Q03431',
#   'HGNC': '9608',
#   'Genatlas': 'PTH1R',
#   'IUPHAR': '331'},
#  {'GARD_ID': 80,
#   'GARD_Disease': 'Johanson-Blizzard syndrome',
#   'Disease_Gene_Association': 'Disease-causing germline mutation(s) (loss of function) in',
#   'Gene_Symbol': 'UBR1',
#   'Gene_Name': 'ubiquitin protein ligase E3 component n-recognin 1',
#   'Gene_Refs': ['SwissProt:Q8IWV7',
#    'Reactome:Q8IWV7',
#    'OMIM:605981',
#    'HGNC:16808',
#    'Genatlas:UBR1',
#    'Ensembl:ENSG00000159459'],
#   'SwissProt': 'Q8IWV7',
#   'Reactome': 'Q8IWV7',
#   'OMIM': '605981',
#   'HGNC': '16808',
#   'Genatlas': 'UBR1',
#   'Ensembl': 'ENSG00000159459'},
#  {'GARD_ID': 81,
#   'GARD_Disease': 'Juberg Marsidi syndrome',
#   'Disease_Gene_Association': None,
#   'Gene_Symbol': None,
#   'Gene_Name': None,
#   'Gene_Refs': None},
#  {'GARD_ID': 82,
#   'GARD_Disease': 'KBG syndrome',
#   'Disease_Gene_Association': 'Disease-causing germline mutation(s) in',
#   'Gene_Symbol': 'ANKRD11',
#   'Gene_Name': 'ankyrin repeat domain 11',
#   'Gene_Refs': ['Ensembl:ENSG00000167522',
#    'Genatlas:ANKRD11',
#    'HGNC:21316',
#    'OMIM:611192',
#    'SwissProt:Q6UB99'],
#   'Ensembl': 'ENSG00000167522',
#   'Genatlas': 'ANKRD11',
#   'HGNC': '21316',
#   'OMIM': '611192',
#   'SwissProt': 'Q6UB99'},
#  {'GARD_ID': 83,
#   'GARD_Disease': 'Kenny-Caffey syndrome type 2',
#   'Disease_Gene_Association': 'Disease-causing germline mutation(s) in',
#   'Gene_Symbol': 'FAM111A',
#   'Gene_Name': 'family with sequence similarity 111 member A',
#   'Gene_Refs': ['OMIM:615292',
#    'Genatlas:FAM111A',
#    'Ensembl:ENSG00000166801',
#    'SwissProt:Q96PZ2',
#    'HGNC:24725'],
#   'OMIM': '615292',
#   'Genatlas': 'FAM111A',
#   'Ensembl': 'ENSG00000166801',
#   'SwissProt': 'Q96PZ2',
#   'HGNC': '24725'},
#  {'GARD_ID': 84,
#   'GARD_Disease': 'Congenital generalized lipodystrophy type 1',
#   'Disease_Gene_Association': None,
#   'Gene_Symbol': None,
#   'Gene_Name': None,
#   'Gene_Refs': None},
#  {'GARD_ID': 85,
#   'GARD_Disease': 'Thanatophoric dysplasia',
#   'Disease_Gene_Association': None,
#   'Gene_Symbol': None,
#   'Gene_Name': None,
#   'Gene_Refs': None},
#  {'GARD_ID': 86,
#   'GARD_Disease': 'Chudley-Mccullough syndrome',
#   'Disease_Gene_Association': 'Disease-causing germline mutation(s) in',
#   'Gene_Symbol': 'GPSM2',
#   'Gene_Name': 'G protein signaling modulator 2',
#   'Gene_Refs': ['Genatlas:GPSM2',
#    'SwissProt:P81274',
#    'Reactome:P81274',
#    'OMIM:609245',
#    'Ensembl:ENSG00000121957',
#    'HGNC:29501'],
#   'Genatlas': 'GPSM2',
#   'SwissProt': 'P81274',
#   'Reactome': 'P81274',
#   'OMIM': '609245',
#   'Ensembl': 'ENSG00000121957',
#   'HGNC': '29501'},
#  {'GARD_ID': 87,
#   'GARD_Disease': 'Lenz microphthalmia syndrome',
#   'Disease_Gene_Association': 'Disease-causing germline mutation(s) in',
#   'Gene_Symbol': 'BCOR',
#   'Gene_Name': 'BCL6 corepressor',
#   'Gene_Refs': ['OMIM:300485',
#    'Ensembl:ENSG00000183337',
#    'HGNC:20893',
#    'Genatlas:BCOR',
#    'Reactome:Q6W2J9',
#    'SwissProt:Q6W2J9'],
#   'OMIM': '300485',
#   'Ensembl': 'ENSG00000183337',
#   'HGNC': '20893',
#   'Genatlas': 'BCOR',
#   'Reactome': 'Q6W2J9',
#   'SwissProt': 'Q6W2J9'},
#  {'GARD_ID': 87,
#   'GARD_Disease': 'Lenz microphthalmia syndrome',
#   'Disease_Gene_Association': 'Disease-causing germline mutation(s) in',
#   'Gene_Symbol': 'NAA10',
#   'Gene_Name': 'N(alpha)-acetyltransferase 10, NatA catalytic subunit',
#   'Gene_Refs': ['Ensembl:ENSG00000102030',
#    'SwissProt:P41227',
#    'Reactome:P41227',
#    'OMIM:300013',
#    'HGNC:18704',
#    'Genatlas:ARD1A'],
#   'Ensembl': 'ENSG00000102030',
#   'SwissProt': 'P41227',
#   'Reactome': 'P41227',
#   'OMIM': '300013',
#   'HGNC': '18704',
#   'Genatlas': 'ARD1A'},
#  {'GARD_ID': 88,
#   'GARD_Disease': 'Leri pleonosteosis',
#   'Disease_Gene_Association': None,
#   'Gene_Symbol': None,
#   'Gene_Name': None,
#   'Gene_Refs': None},
#  {'GARD_ID': 89,
#   'GARD_Disease': 'Gastric Non-Hodgkin Lymphoma',
#   'Disease_Gene_Association': None,
#   'Gene_Symbol': None,
#   'Gene_Name': None,
#   'Gene_Refs': None},
#  {'GARD_ID': 91,
#   'GARD_Disease': 'Malignant melanoma, childhood',
#   'Disease_Gene_Association': None,
#   'Gene_Symbol': None,
#   'Gene_Name': None,
#   'Gene_Refs': None},
#  {'GARD_ID': 92,
#   'GARD_Disease': 'Meleda disease',
#   'Disease_Gene_Association': 'Disease-causing germline mutation(s) in',
#   'Gene_Symbol': 'SLURP1',
#   'Gene_Name': 'secreted LY6/PLAUR domain containing 1',
#   'Gene_Refs': ['OMIM:606119',
#    'HGNC:18746',
#    'Ensembl:ENSG00000126233',
#    'SwissProt:P55000',
#    'Genatlas:SLURP1'],
#   'OMIM': '606119',
#   'HGNC': '18746',
#   'Ensembl': 'ENSG00000126233',
#   'SwissProt': 'P55000',
#   'Genatlas': 'SLURP1'},
#  {'GARD_ID': 93,
#   'GARD_Disease': 'Monilethrix',
#   'Disease_Gene_Association': 'Disease-causing germline mutation(s) in',
#   'Gene_Symbol': 'KRT86',
#   'Gene_Name': 'keratin 86',
#   'Gene_Refs': ['SwissProt:O43790',
#    'OMIM:601928',
#    'Ensembl:ENSG00000170442',
#    'HGNC:6463',
#    'Reactome:O43790',
#    'Genatlas:KRT86'],
#   'SwissProt': 'O43790',
#   'OMIM': '601928',
#   'Ensembl': 'ENSG00000170442',
#   'HGNC': '6463',
#   'Reactome': 'O43790',
#   'Genatlas': 'KRT86'},
#  {'GARD_ID': 93,
#   'GARD_Disease': 'Monilethrix',
#   'Disease_Gene_Association': 'Disease-causing germline mutation(s) in',
#   'Gene_Symbol': 'KRT83',
#   'Gene_Name': 'keratin 83',
#   'Gene_Refs': ['SwissProt:P78385',
#    'Reactome:P78385',
#    'Genatlas:KRT83',
#    'Ensembl:ENSG00000170523',
#    'OMIM:602765',
#    'HGNC:6460'],
#   'SwissProt': 'P78385',
#   'Reactome': 'P78385',
#   'Genatlas': 'KRT83',
#   'Ensembl': 'ENSG00000170523',
#   'OMIM': '602765',
#   'HGNC': '6460'},
#  {'GARD_ID': 93,
#   'GARD_Disease': 'Monilethrix',
#   'Disease_Gene_Association': 'Disease-causing germline mutation(s) in',
#   'Gene_Symbol': 'KRT81',
#   'Gene_Name': 'keratin 81',
#   'Gene_Refs': ['Ensembl:ENSG00000205426',
#    'Genatlas:KRT81',
#    'OMIM:602153',
#    'SwissProt:Q14533',
#    'Reactome:Q14533',
#    'HGNC:6458'],
#   'Ensembl': 'ENSG00000205426',
#   'Genatlas': 'KRT81',
#   'OMIM': '602153',
#   'SwissProt': 'Q14533',
#   'Reactome': 'Q14533',
#   'HGNC': '6458'},
#  {'GARD_ID': 93,
#   'GARD_Disease': 'Monilethrix',
#   'Disease_Gene_Association': 'Disease-causing germline mutation(s) in',
#   'Gene_Symbol': 'DSG4',
#   'Gene_Name': 'desmoglein 4',
#   'Gene_Refs': ['OMIM:607892',
#    'HGNC:21307',
#    'Ensembl:ENSG00000175065',
#    'SwissProt:Q86SJ6',
#    'Genatlas:DSG4',
#    'Reactome:Q86SJ6'],
#   'OMIM': '607892',
#   'HGNC': '21307',
#   'Ensembl': 'ENSG00000175065',
#   'SwissProt': 'Q86SJ6',
#   'Genatlas': 'DSG4',
#   'Reactome': 'Q86SJ6'},
#  {'GARD_ID': 94,
#   'GARD_Disease': 'Mucolipidosis type 4',
#   'Disease_Gene_Association': 'Disease-causing germline mutation(s) (loss of function) in',
#   'Gene_Symbol': 'MCOLN1',
#   'Gene_Name': 'mucolipin 1',
#   'Gene_Refs': ['SwissProt:Q9GZU1',
#    'Genatlas:MCOLN1',
#    'IUPHAR:501',
#    'Reactome:Q9GZU1',
#    'OMIM:605248',
#    'HGNC:13356',
#    'Ensembl:ENSG00000090674'],
#   'SwissProt': 'Q9GZU1',
#   'Genatlas': 'MCOLN1',
#   'IUPHAR': '501',
#   'Reactome': 'Q9GZU1',
#   'OMIM': '605248',
#   'HGNC': '13356',
#   'Ensembl': 'ENSG00000090674'},
#  {'GARD_ID': 95,
#   'GARD_Disease': 'Mulibrey Nanism',
#   'Disease_Gene_Association': 'Disease-causing germline mutation(s) in',
#   'Gene_Symbol': 'TRIM37',
#   'Gene_Name': 'tripartite motif containing 37',
#   'Gene_Refs': ['OMIM:605073',
#    'Reactome:O94972',
#    'SwissProt:O94972',
#    'HGNC:7523',
#    'Ensembl:ENSG00000108395',
#    'Genatlas:TRIM37'],
#   'OMIM': '605073',
#   'Reactome': 'O94972',
#   'SwissProt': 'O94972',
#   'HGNC': '7523',
#   'Ensembl': 'ENSG00000108395',
#   'Genatlas': 'TRIM37'},
#  {'GARD_ID': 101,
#   'GARD_Disease': 'Centronuclear myopathy',
#   'Disease_Gene_Association': None,
#   'Gene_Symbol': None,
#   'Gene_Name': None,
#   'Gene_Refs': None},
#  {'GARD_ID': 102,
#   'GARD_Disease': 'Neu Laxova syndrome',
#   'Disease_Gene_Association': 'Disease-causing germline mutation(s) (loss of function) in',
#   'Gene_Symbol': 'PHGDH',
#   'Gene_Name': 'phosphoglycerate dehydrogenase',
#   'Gene_Refs': ['OMIM:606879',
#    'HGNC:8923',
#    'Genatlas:PHGDH',
#    'Ensembl:ENSG00000092621',
#    'Reactome:O43175',
#    'SwissProt:O43175'],
#   'OMIM': '606879',
#   'HGNC': '8923',
#   'Genatlas': 'PHGDH',
#   'Ensembl': 'ENSG00000092621',
#   'Reactome': 'O43175',
#   'SwissProt': 'O43175'},
#  {'GARD_ID': 102,
#   'GARD_Disease': 'Neu Laxova syndrome',
#   'Disease_Gene_Association': 'Disease-causing germline mutation(s) in',
#   'Gene_Symbol': 'PSAT1',
#   'Gene_Name': 'phosphoserine aminotransferase 1',
#   'Gene_Refs': ['HGNC:19129',
#    'Ensembl:ENSG00000135069',
#    'OMIM:610936',
#    'SwissProt:Q9Y617',
#    'Reactome:Q9Y617',
#    'Genatlas:PSAT1'],
#   'HGNC': '19129',
#   'Ensembl': 'ENSG00000135069',
#   'OMIM': '610936',
#   'SwissProt': 'Q9Y617',
#   'Reactome': 'Q9Y617',
#   'Genatlas': 'PSAT1'},
#  {'GARD_ID': 104,
#   'GARD_Disease': 'Ochoa syndrome',
#   'Disease_Gene_Association': 'Disease-causing germline mutation(s) in',
#   'Gene_Symbol': 'HPSE2',
#   'Gene_Name': 'heparanase 2 (inactive)',
#   'Gene_Refs': ['Ensembl:ENSG00000172987',
#    'Genatlas:HPSE2',
#    'SwissProt:Q8WWQ2',
#    'OMIM:613469',
#    'Reactome:Q8WWQ2',
#    'HGNC:18374'],
#   'Ensembl': 'ENSG00000172987',
#   'Genatlas': 'HPSE2',
#   'SwissProt': 'Q8WWQ2',
#   'OMIM': '613469',
#   'Reactome': 'Q8WWQ2',
#   'HGNC': '18374'},
#  {'GARD_ID': 104,
#   'GARD_Disease': 'Ochoa syndrome',
#   'Disease_Gene_Association': 'Disease-causing germline mutation(s) in',
#   'Gene_Symbol': 'LRIG2',
#   'Gene_Name': 'leucine rich repeats and immunoglobulin like domains 2',
#   'Gene_Refs': ['SwissProt:O94898',
#    'Genatlas:LRIG2',
#    'OMIM:608869',
#    'HGNC:20889',
#    'Ensembl:ENSG00000198799'],
#   'SwissProt': 'O94898',
#   'Genatlas': 'LRIG2',
#   'OMIM': '608869',
#   'HGNC': '20889',
#   'Ensembl': 'ENSG00000198799'},
#  {'GARD_ID': 105,
#   'GARD_Disease': 'Oculocerebral syndrome with hypopigmentation',
#   'Disease_Gene_Association': None,
#   'Gene_Symbol': None,
#   'Gene_Name': None,
#   'Gene_Refs': None},
#  {'GARD_ID': 106,
#   'GARD_Disease': 'Oculocerebrocutaneous syndrome',
#   'Disease_Gene_Association': None,
#   'Gene_Symbol': None,
#   'Gene_Name': None,
#   'Gene_Refs': None},
#  {'GARD_ID': 108,
#   'GARD_Disease': 'Adult polyglucosan body disease',
#   'Disease_Gene_Association': 'Disease-causing germline mutation(s) in',
#   'Gene_Symbol': 'GBE1',
#   'Gene_Name': '1,4-alpha-glucan branching enzyme 1',
#   'Gene_Refs': ['Genatlas:GBE1',
#    'OMIM:607839',
#    'HGNC:4180',
#    'Ensembl:ENSG00000114480',
#    'Reactome:Q04446',
#    'SwissProt:Q04446'],
#   'Genatlas': 'GBE1',
#   'OMIM': '607839',
#   'HGNC': '4180',
#   'Ensembl': 'ENSG00000114480',
#   'Reactome': 'Q04446',
#   'SwissProt': 'Q04446'},
#  {'GARD_ID': 109,
#   'GARD_Disease': 'Progressive osseous heteroplasia',
#   'Disease_Gene_Association': 'Disease-causing germline mutation(s) (loss of function) in',
#   'Gene_Symbol': 'GNAS',
#   'Gene_Name': 'GNAS complex locus',
#   'Gene_Refs': ['Genatlas:GNAS',
#    'SwissProt:Q5JWF2',
#    'SwissProt:P84996',
#    'SwissProt:P63092',
#    'OMIM:139320',
#    'Reactome:Q5JWF2',
#    'SwissProt:O95467',
#    'Reactome:P63092',
#    'Ensembl:ENSG00000087460',
#    'HGNC:4392'],
#   'Genatlas': 'GNAS',
#   'SwissProt': 'O95467',
#   'OMIM': '139320',
#   'Reactome': 'P63092',
#   'Ensembl': 'ENSG00000087460',
#   'HGNC': '4392'},
#  {'GARD_ID': 111,
#   'GARD_Disease': 'Recurrent respiratory papillomatosis',
#   'Disease_Gene_Association': None,
#   'Gene_Symbol': None,
#   'Gene_Name': None,
#   'Gene_Refs': None},
#  {'GARD_ID': 112,
#   'GARD_Disease': 'Respiratory distress syndrome, infant',
#   'Disease_Gene_Association': 'Major susceptibility factor in',
#   'Gene_Symbol': 'SFTPB',
#   'Gene_Name': 'surfactant protein B',
#   'Gene_Refs': ['SwissProt:P07988',
#    'Reactome:P07988',
#    'OMIM:178640',
#    'HGNC:10801',
#    'Ensembl:ENSG00000168878',
#    'Genatlas:SFTPB'],
#   'SwissProt': 'P07988',
#   'Reactome': 'P07988',
#   'OMIM': '178640',
#   'HGNC': '10801',
#   'Ensembl': 'ENSG00000168878',
#   'Genatlas': 'SFTPB'},
#  {'GARD_ID': 112,
#   'GARD_Disease': 'Respiratory distress syndrome, infant',
#   'Disease_Gene_Association': 'Major susceptibility factor in',
#   'Gene_Symbol': 'SFTPC',
#   'Gene_Name': 'surfactant protein C',
#   'Gene_Refs': ['Genatlas:SFTPC',
#    'Ensembl:ENSG00000168484',
#    'SwissProt:P11686',
#    'OMIM:178620',
#    'Reactome:P11686',
#    'HGNC:10802'],
#   'Genatlas': 'SFTPC',
#   'Ensembl': 'ENSG00000168484',
#   'SwissProt': 'P11686',
#   'OMIM': '178620',
#   'Reactome': 'P11686',
#   'HGNC': '10802'},
#  {'GARD_ID': 112,
#   'GARD_Disease': 'Respiratory distress syndrome, infant',
#   'Disease_Gene_Association': 'Candidate gene tested in',
#   'Gene_Symbol': 'ABCA3',
#   'Gene_Name': 'ATP binding cassette subfamily A member 3',
#   'Gene_Refs': ['OMIM:601615',
#    'SwissProt:Q99758',
#    'HGNC:33',
#    'Ensembl:ENSG00000167972',
#    'Genatlas:ABCA3',
#    'Reactome:Q99758'],
#   'OMIM': '601615',
#   'SwissProt': 'Q99758',
#   'HGNC': '33',
#   'Ensembl': 'ENSG00000167972',
#   'Genatlas': 'ABCA3',
#   'Reactome': 'Q99758'},
#  {'GARD_ID': 113,
#   'GARD_Disease': 'Retinopathy, arteriosclerotic',
#   'Disease_Gene_Association': None,
#   'Gene_Symbol': None,
#   'Gene_Name': None,
#   'Gene_Refs': None},
#  {'GARD_ID': 114,
#   'GARD_Disease': 'X-linked Charcot-Marie-Tooth disease type 5',
#   'Disease_Gene_Association': 'Disease-causing germline mutation(s) in',
#   'Gene_Symbol': 'PRPS1',
#   'Gene_Name': 'phosphoribosyl pyrophosphate synthetase 1',
#   'Gene_Refs': ['OMIM:311850',
#    'Ensembl:ENSG00000147224',
#    'Genatlas:PRPS1',
#    'SwissProt:P60891',
#    'Reactome:P60891',
#    'HGNC:9462'],
#   'OMIM': '311850',
#   'Ensembl': 'ENSG00000147224',
#   'Genatlas': 'PRPS1',
#   'SwissProt': 'P60891',
#   'Reactome': 'P60891',
#   'HGNC': '9462'},
#  {'GARD_ID': 116,
#   'GARD_Disease': 'Schindler disease type 1',
#   'Disease_Gene_Association': 'Disease-causing germline mutation(s) in',
#   'Gene_Symbol': 'NAGA',
#   'Gene_Name': 'alpha-N-acetylgalactosaminidase',
#   'Gene_Refs': ['Ensembl:ENSG00000198951',
#    'SwissProt:P17050',
#    'OMIM:104170',
#    'HGNC:7631',
#    'Genatlas:NAGA'],
#   'Ensembl': 'ENSG00000198951',
#   'SwissProt': 'P17050',
#   'OMIM': '104170',
#   'HGNC': '7631',
#   'Genatlas': 'NAGA'},
#  {'GARD_ID': 117,
#   'GARD_Disease': 'Schinzel Giedion syndrome',
#   'Disease_Gene_Association': 'Disease-causing germline mutation(s) (gain of function) in',
#   'Gene_Symbol': 'SETBP1',
#   'Gene_Name': 'SET binding protein 1',
#   'Gene_Refs': ['HGNC:15573',
#    'Ensembl:ENSG00000152217',
#    'OMIM:611060',
#    'SwissProt:Q9Y6X0',
#    'Genatlas:SETBP1'],
#   'HGNC': '15573',
#   'Ensembl': 'ENSG00000152217',
#   'OMIM': '611060',
#   'SwissProt': 'Q9Y6X0',
#   'Genatlas': 'SETBP1'},
#  {'GARD_ID': 118,
#   'GARD_Disease': 'Ulnar-mammary syndrome',
#   'Disease_Gene_Association': 'Disease-causing germline mutation(s) (loss of function) in',
#   'Gene_Symbol': 'TBX3',
#   'Gene_Name': 'T-box 3',
#   'Gene_Refs': ['Genatlas:TBX3',
#    'Reactome:O15119',
#    'Ensembl:ENSG00000135111',
#    'OMIM:601621',
#    'SwissProt:O15119',
#    'HGNC:11602'],
#   'Genatlas': 'TBX3',
#   'Reactome': 'O15119',
#   'Ensembl': 'ENSG00000135111',
#   'OMIM': '601621',
#   'SwissProt': 'O15119',
#   'HGNC': '11602'},
#  {'GARD_ID': 120,
#   'GARD_Disease': 'Sennetsu Fever',
#   'Disease_Gene_Association': None,
#   'Gene_Symbol': None,
#   'Gene_Name': None,
#   'Gene_Refs': None},
#  {'GARD_ID': 121,
#   'GARD_Disease': 'Facial ectodermal dysplasia',
#   'Disease_Gene_Association': 'Disease-causing germline mutation(s) in',
#   'Gene_Symbol': 'TWIST2',
#   'Gene_Name': 'twist family bHLH transcription factor 2',
#   'Gene_Refs': ['Ensembl:ENSG00000233608',
#    'OMIM:607556',
#    'Reactome:Q8WVJ9',
#    'Genatlas:TWIST2',
#    'SwissProt:Q8WVJ9',
#    'HGNC:20670'],
#   'Ensembl': 'ENSG00000233608',
#   'OMIM': '607556',
#   'Reactome': 'Q8WVJ9',
#   'Genatlas': 'TWIST2',
#   'SwissProt': 'Q8WVJ9',
#   'HGNC': '20670'},
#  {'GARD_ID': 122,
#   'GARD_Disease': 'Singleton-Merten syndrome',
#   'Disease_Gene_Association': 'Disease-causing germline mutation(s) (gain of function) in',
#   'Gene_Symbol': 'IFIH1',
#   'Gene_Name': 'interferon induced with helicase C domain 1',
#   'Gene_Refs': ['SwissProt:Q9BYX4',
#    'Ensembl:ENSG00000115267',
#    'Genatlas:IFIH1',
#    'HGNC:18873',
#    'Reactome:Q9BYX4',
#    'OMIM:606951'],
#   'SwissProt': 'Q9BYX4',
#   'Ensembl': 'ENSG00000115267',
#   'Genatlas': 'IFIH1',
#   'HGNC': '18873',
#   'Reactome': 'Q9BYX4',
#   'OMIM': '606951'},
#  {'GARD_ID': 122,
#   'GARD_Disease': 'Singleton-Merten syndrome',
#   'Disease_Gene_Association': 'Disease-causing germline mutation(s) in',
#   'Gene_Symbol': 'DDX58',
#   'Gene_Name': 'DExD/H-box helicase 58',
#   'Gene_Refs': ['Reactome:O95786',
#    'Genatlas:DDX58',
#    'OMIM:609631',
#    'SwissProt:O95786',
#    'HGNC:19102',
#    'Ensembl:ENSG00000107201'],
#   'Reactome': 'O95786',
#   'Genatlas': 'DDX58',
#   'OMIM': '609631',
#   'SwissProt': 'O95786',
#   'HGNC': '19102',
#   'Ensembl': 'ENSG00000107201'},
#  {'GARD_ID': 124,
#   'GARD_Disease': 'Allain-Babin-Demarquez syndrome',
#   'Disease_Gene_Association': None,
#   'Gene_Symbol': None,
#   'Gene_Name': None,
#   'Gene_Refs': None},
#  {'GARD_ID': 125,
#   'GARD_Disease': 'Acrokeratoelastoidosis of Costa',
#   'Disease_Gene_Association': None,
#   'Gene_Symbol': None,
#   'Gene_Name': None,
#   'Gene_Refs': None},
#  {'GARD_ID': 130,
#   'GARD_Disease': 'Florid cystic endosalpingiosis of the uterus',
#   'Disease_Gene_Association': None,
#   'Gene_Symbol': None,
#   'Gene_Name': None,
#   'Gene_Refs': None},
#  {'GARD_ID': 132,
#   'GARD_Disease': 'Primary cutaneous amyloidosis',
#   'Disease_Gene_Association': 'Disease-causing germline mutation(s) in',
#   'Gene_Symbol': 'OSMR',
#   'Gene_Name': 'oncostatin M receptor',
#   'Gene_Refs': ['Genatlas:OSMR',
#    'Ensembl:ENSG00000145623',
#    'Reactome:Q99650',
#    'OMIM:601743',
#    'SwissProt:Q99650',
#    'HGNC:8507'],
#   'Genatlas': 'OSMR',
#   'Ensembl': 'ENSG00000145623',
#   'Reactome': 'Q99650',
#   'OMIM': '601743',
#   'SwissProt': 'Q99650',
#   'HGNC': '8507'},
#  {'GARD_ID': 132,
#   'GARD_Disease': 'Primary cutaneous amyloidosis',
#   'Disease_Gene_Association': 'Disease-causing germline mutation(s) in',
#   'Gene_Symbol': 'IL31RA',
#   'Gene_Name': 'interleukin 31 receptor A',
#   'Gene_Refs': ['OMIM:609510',
#    'SwissProt:Q8NI17',
#    'Genatlas:IL31RA',
#    'Ensembl:ENSG00000164509',
#    'HGNC:18969',
#    'Reactome:Q8NI17'],
#   'OMIM': '609510',
#   'SwissProt': 'Q8NI17',
#   'Genatlas': 'IL31RA',
#   'Ensembl': 'ENSG00000164509',
#   'HGNC': '18969',
#   'Reactome': 'Q8NI17'},
#  {'GARD_ID': 133,
#   'GARD_Disease': 'Aganglionosis, total intestinal',
#   'Disease_Gene_Association': None,
#   'Gene_Symbol': None,
#   'Gene_Name': None,
#   'Gene_Refs': None},
#  {'GARD_ID': 134,
#   'GARD_Disease': 'Spondyloepimetaphyseal dysplasia Strudwick type',
#   'Disease_Gene_Association': 'Disease-causing germline mutation(s) in',
#   'Gene_Symbol': 'COL2A1',
#   'Gene_Name': 'collagen type II alpha 1 chain',
#   'Gene_Refs': ['Genatlas:COL2A1',
#    'SwissProt:P02458',
#    'OMIM:120140',
#    'Ensembl:ENSG00000139219',
#    'Reactome:P02458',
#    'HGNC:2200'],
#   'Genatlas': 'COL2A1',
#   'SwissProt': 'P02458',
#   'OMIM': '120140',
#   'Ensembl': 'ENSG00000139219',
#   'Reactome': 'P02458',
#   'HGNC': '2200'},
#  {'GARD_ID': 136,
#   'GARD_Disease': 'Dextrocardia with unusual facies and microphthalmia',
#   'Disease_Gene_Association': None,
#   'Gene_Symbol': None,
#   'Gene_Name': None,
#   'Gene_Refs': None},
#  {'GARD_ID': 137,
#   'GARD_Disease': 'Dandy-Walker malformation with nasopharyngeal teratoma and diaphragmatic hernia',
#   'Disease_Gene_Association': None,
#   'Gene_Symbol': None,
#   'Gene_Name': None,
#   'Gene_Refs': None},
#  {'GARD_ID': 139,
#   'GARD_Disease': 'Atrial myxoma, familial',
#   'Disease_Gene_Association': 'Disease-causing germline mutation(s) in',
#   'Gene_Symbol': 'PRKAR1A',
#   'Gene_Name': 'protein kinase cAMP-dependent type I regulatory subunit alpha',
#   'Gene_Refs': ['Reactome:P10644',
#    'SwissProt:P10644',
#    'IUPHAR:1472',
#    'Ensembl:ENSG00000108946',
#    'HGNC:9388',
#    'OMIM:188830',
#    'Genatlas:PRKAR1A'],
#   'Reactome': 'P10644',
#   'SwissProt': 'P10644',
#   'IUPHAR': '1472',
#   'Ensembl': 'ENSG00000108946',
#   'HGNC': '9388',
#   'OMIM': '188830',
#   'Genatlas': 'PRKAR1A'},
#  {'GARD_ID': 140,
#   'GARD_Disease': 'Atresia of small intestine',
#   'Disease_Gene_Association': None,
#   'Gene_Symbol': None,
#   'Gene_Name': None,
#   'Gene_Refs': None},
#  {'GARD_ID': 143,
#   'GARD_Disease': 'Hairy elbows',
#   'Disease_Gene_Association': None,
#   'Gene_Symbol': None,
#   'Gene_Name': None,
#   'Gene_Refs': None},
#  {'GARD_ID': 144,
#   'GARD_Disease': 'Mac Dermot Winter syndrome',
#   'Disease_Gene_Association': None,
#   'Gene_Symbol': None,
#   'Gene_Name': None,
#   'Gene_Refs': None},
#  {'GARD_ID': 147,
#   'GARD_Disease': 'Macrocephaly, benign familial',
#   'Disease_Gene_Association': None,
#   'Gene_Symbol': None,
#   'Gene_Name': None,
#   'Gene_Refs': None},
#  {'GARD_ID': 149,
#   'GARD_Disease': 'Prostatic malacoplakia associated with prostatic abscess',
#   'Disease_Gene_Association': None,
#   'Gene_Symbol': None,
#   'Gene_Name': None,
#   'Gene_Refs': None},
#  {'GARD_ID': 150,
#   'GARD_Disease': 'Sammartino Decreccio syndrome',
#   'Disease_Gene_Association': None,
#   'Gene_Symbol': None,
#   'Gene_Name': None,
#   'Gene_Refs': None},
#  {'GARD_ID': 151,
#   'GARD_Disease': 'Samson Gardner syndrome',
#   'Disease_Gene_Association': None,
#   'Gene_Symbol': None,
#   'Gene_Name': None,
#   'Gene_Refs': None},
#  {'GARD_ID': 152,
#   'GARD_Disease': 'Samson Viljoen syndrome',
#   'Disease_Gene_Association': None,
#   'Gene_Symbol': None,
#   'Gene_Name': None,
#   'Gene_Refs': None},
#  {'GARD_ID': 153,
#   'GARD_Disease': 'Sanderson Fraser syndrome',
#   'Disease_Gene_Association': None,
#   'Gene_Symbol': None,
#   'Gene_Name': None,
#   'Gene_Refs': None},
#  {'GARD_ID': 154,
#   'GARD_Disease': 'Sandhaus Ben-Ami syndrome',
#   'Disease_Gene_Association': None,
#   'Gene_Symbol': None,
#   'Gene_Name': None,
#   'Gene_Refs': None},
#  {'GARD_ID': 155,
#   'GARD_Disease': 'Laurin-Sandrow syndrome',
#   'Disease_Gene_Association': 'Disease-causing germline mutation(s) in',
#   'Gene_Symbol': 'LMBR1',
#   'Gene_Name': 'limb development membrane protein 1',
#   'Gene_Refs': ['Genatlas:LMBR1',
#    'HGNC:13243',
#    'SwissProt:Q8WVP7',
#    'OMIM:605522',
#    'Ensembl:ENSG00000105983'],
#   'Genatlas': 'LMBR1',
#   'HGNC': '13243',
#   'SwissProt': 'Q8WVP7',
#   'OMIM': '605522',
#   'Ensembl': 'ENSG00000105983'},
#  {'GARD_ID': 156,
#   'GARD_Disease': 'Muscle eye brain disease',
#   'Disease_Gene_Association': 'Candidate gene tested in',
#   'Gene_Symbol': 'LARGE1',
#   'Gene_Name': 'LARGE xylosyl- and glucuronyltransferase 1',
#   'Gene_Refs': ['SwissProt:O95461',
#    'Ensembl:ENSG00000133424',
#    'OMIM:603590',
#    'HGNC:6511',
#    'Genatlas:LARGE',
#    'Reactome:O95461'],
#   'SwissProt': 'O95461',
#   'Ensembl': 'ENSG00000133424',
#   'OMIM': '603590',
#   'HGNC': '6511',
#   'Genatlas': 'LARGE',
#   'Reactome': 'O95461'},
#  {'GARD_ID': 156,
#   'GARD_Disease': 'Muscle eye brain disease',
#   'Disease_Gene_Association': 'Disease-causing germline mutation(s) (loss of function) in',
#   'Gene_Symbol': 'POMGNT1',
#   'Gene_Name': 'protein O-linked mannose N-acetylglucosaminyltransferase 1 (beta 1,2-)',
#   'Gene_Refs': ['OMIM:606822',
#    'SwissProt:Q8WZA1',
#    'HGNC:19139',
#    'Reactome:Q8WZA1',
#    'Ensembl:ENSG00000085998',
#    'Genatlas:POMGNT1'],
#   'OMIM': '606822',
#   'SwissProt': 'Q8WZA1',
#   'HGNC': '19139',
#   'Reactome': 'Q8WZA1',
# ...
#   'Gene_Refs': ['SwissProt:Q13614',
#    'Genatlas:MTMR2',
#    'HGNC:7450',
#    'Reactome:Q13614',
#    'Ensembl:ENSG00000087053',
#    'OMIM:603557'],
#   'SwissProt': 'Q13614',
#   'Genatlas': 'MTMR2',
#   'HGNC': '7450',
#   'Reactome': 'Q13614',
#   'Ensembl': 'ENSG00000087053',
#   'OMIM': '603557'},
#  {'GARD_ID': 1258,
#   'GARD_Disease': 'X-linked Charcot-Marie-Tooth disease type 1',
#   'Disease_Gene_Association': 'Disease-causing germline mutation(s) in',
#   'Gene_Symbol': 'GJB1',
#   'Gene_Name': 'gap junction protein beta 1',
#   'Gene_Refs': ['OMIM:304040',
#    'Genatlas:GJB1',
#    'Reactome:P08034',
#    'SwissProt:P08034',
#    'HGNC:4283',
#    'Ensembl:ENSG00000169562'],
#   'OMIM': '304040',
#   'Genatlas': 'GJB1',
#   'Reactome': 'P08034',
#   'SwissProt': 'P08034',
#   'HGNC': '4283',
#   'Ensembl': 'ENSG00000169562'},
#  {'GARD_ID': 1261,
#   'GARD_Disease': 'Charlie M syndrome',
#   'Disease_Gene_Association': None,
#   'Gene_Symbol': None,
#   'Gene_Name': None,
#   'Gene_Refs': None},
#  {'GARD_ID': 1265,
#   'GARD_Disease': 'Abdominal chemodectomas with cutaneous angiolipomas',
#   'Disease_Gene_Association': None,
#   'Gene_Symbol': None,
#   'Gene_Name': None,
#   'Gene_Refs': None},
#  {'GARD_ID': 1266,
#   'GARD_Disease': 'Ho Kaufman Mcalister syndrome',
#   'Disease_Gene_Association': None,
#   'Gene_Symbol': None,
#   'Gene_Name': None,
#   'Gene_Refs': None},
#  {'GARD_ID': 1274,
#   'GARD_Disease': 'Chitayat Meunier Hodgkinson syndrome',
#   'Disease_Gene_Association': None,
#   'Gene_Symbol': None,
#   'Gene_Name': None,
#   'Gene_Refs': None},
#  {'GARD_ID': 1277,
#   'GARD_Disease': 'Chitty Hall Webb syndrome',
#   'Disease_Gene_Association': None,
#   'Gene_Symbol': None,
#   'Gene_Name': None,
#   'Gene_Refs': None},
#  {'GARD_ID': 1280,
#   'GARD_Disease': 'Primary sclerosing cholangitis',
#   'Disease_Gene_Association': 'Major susceptibility factor in',
#   'Gene_Symbol': 'GPR35',
#   'Gene_Name': 'G protein-coupled receptor 35',
#   'Gene_Refs': ['IUPHAR:102',
#    'SwissProt:Q9HC97',
#    'Ensembl:ENSG00000178623',
#    'Reactome:Q9HC97',
#    'HGNC:4492',
#    'Genatlas:GPR35',
#    'OMIM:602646'],
#   'IUPHAR': '102',
#   'SwissProt': 'Q9HC97',
#   'Ensembl': 'ENSG00000178623',
#   'Reactome': 'Q9HC97',
#   'HGNC': '4492',
#   'Genatlas': 'GPR35',
#   'OMIM': '602646'},
#  {'GARD_ID': 1280,
#   'GARD_Disease': 'Primary sclerosing cholangitis',
#   'Disease_Gene_Association': 'Major susceptibility factor in',
#   'Gene_Symbol': 'MST1',
#   'Gene_Name': 'macrophage stimulating 1',
#   'Gene_Refs': ['SwissProt:P26927',
#    'Genatlas:MST1',
#    'Ensembl:ENSG00000173531',
#    'HGNC:7380',
#    'Reactome:P26927',
#    'OMIM:142408'],
#   'SwissProt': 'P26927',
#   'Genatlas': 'MST1',
#   'Ensembl': 'ENSG00000173531',
#   'HGNC': '7380',
#   'Reactome': 'P26927',
#   'OMIM': '142408'},
#  {'GARD_ID': 1280,
#   'GARD_Disease': 'Primary sclerosing cholangitis',
#   'Disease_Gene_Association': 'Major susceptibility factor in',
#   'Gene_Symbol': 'TCF4',
#   'Gene_Name': 'transcription factor 4',
#   'Gene_Refs': ['HGNC:11634',
#    'Ensembl:ENSG00000196628',
#    'SwissProt:P15884',
#    'OMIM:602272',
#    'Reactome:P15884',
#    'Genatlas:TCF4'],
#   'HGNC': '11634',
#   'Ensembl': 'ENSG00000196628',
#   'SwissProt': 'P15884',
#   'OMIM': '602272',
#   'Reactome': 'P15884',
#   'Genatlas': 'TCF4'},
#  {'GARD_ID': 1288,
#   'GARD_Disease': 'Progressive familial intrahepatic cholestasis type 2',
#   'Disease_Gene_Association': 'Disease-causing germline mutation(s) (loss of function) in',
#   'Gene_Symbol': 'ABCB11',
#   'Gene_Name': 'ATP binding cassette subfamily B member 11',
#   'Gene_Refs': ['Reactome:O95342',
#    'Genatlas:ABCB11',
#    'SwissProt:O95342',
#    'OMIM:603201',
#    'HGNC:42',
#    'Ensembl:ENSG00000073734'],
#   'Reactome': 'O95342',
#   'Genatlas': 'ABCB11',
#   'SwissProt': 'O95342',
#   'OMIM': '603201',
#   'HGNC': '42',
#   'Ensembl': 'ENSG00000073734'},
#  {'GARD_ID': 1289,
#   'GARD_Disease': 'Progressive familial intrahepatic cholestasis type 3',
#   'Disease_Gene_Association': 'Disease-causing germline mutation(s) (loss of function) in',
#   'Gene_Symbol': 'ABCB4',
#   'Gene_Name': 'ATP binding cassette subfamily B member 4',
#   'Gene_Refs': ['Genatlas:ABCB4',
#    'HGNC:45',
#    'OMIM:171060',
#    'Reactome:P21439',
#    'SwissProt:P21439',
#    'Ensembl:ENSG00000005471'],
#   'Genatlas': 'ABCB4',
#   'HGNC': '45',
#   'OMIM': '171060',
#   'Reactome': 'P21439',
#   'SwissProt': 'P21439',
#   'Ensembl': 'ENSG00000005471'},
#  {'GARD_ID': 1292,
#   'GARD_Disease': 'Chondrocalcinosis 2',
#   'Disease_Gene_Association': 'Disease-causing germline mutation(s) in',
#   'Gene_Symbol': 'ANKH',
#   'Gene_Name': 'ANKH inorganic pyrophosphate transport regulator',
#   'Gene_Refs': ['Reactome:Q9HCJ1',
#    'HGNC:15492',
#    'Ensembl:ENSG00000154122',
#    'OMIM:605145',
#    'Genatlas:ANKH',
#    'SwissProt:Q9HCJ1'],
#   'Reactome': 'Q9HCJ1',
#   'HGNC': '15492',
#   'Ensembl': 'ENSG00000154122',
#   'OMIM': '605145',
#   'Genatlas': 'ANKH',
#   'SwissProt': 'Q9HCJ1'},
#  {'GARD_ID': 1294,
#   'GARD_Disease': 'Lethal recessive chondrodysplasia',
#   'Disease_Gene_Association': None,
#   'Gene_Symbol': None,
#   'Gene_Name': None,
#   'Gene_Refs': None},
#  {'GARD_ID': 1296,
#   'GARD_Disease': 'Chondrodysplasia punctata 1, X-linked recessive',
#   'Disease_Gene_Association': 'Disease-causing germline mutation(s) in',
#   'Gene_Symbol': 'ARSE',
#   'Gene_Name': 'arylsulfatase E',
#   'Gene_Refs': ['Reactome:P51690',
#    'Ensembl:ENSG00000157399',
#    'OMIM:300180',
#    'HGNC:719',
#    'Genatlas:ARSE',
#    'SwissProt:P51690'],
#   'Reactome': 'P51690',
#   'Ensembl': 'ENSG00000157399',
#   'OMIM': '300180',
#   'HGNC': '719',
#   'Genatlas': 'ARSE',
#   'SwissProt': 'P51690'},
#  {'GARD_ID': 1298,
#   'GARD_Disease': 'Chondrodysplasia punctata Sheffield type',
#   'Disease_Gene_Association': None,
#   'Gene_Symbol': None,
#   'Gene_Name': None,
#   'Gene_Refs': None},
#  {'GARD_ID': 1299,
#   'GARD_Disease': 'Chondrodysplasia situs inversus imperforate anus polydactyly',
#   'Disease_Gene_Association': None,
#   'Gene_Symbol': None,
#   'Gene_Name': None,
#   'Gene_Refs': None},
#  {'GARD_ID': 1300,
#   'GARD_Disease': 'Chondrodysplasia, Grebe type',
#   'Disease_Gene_Association': 'Disease-causing germline mutation(s) (loss of function) in',
#   'Gene_Symbol': 'BMPR1B',
#   'Gene_Name': 'bone morphogenetic protein receptor type 1B',
#   'Gene_Refs': ['Genatlas:BMPR1B',
#    'Ensembl:ENSG00000138696',
#    'Reactome:O00238',
#    'SwissProt:O00238',
#    'HGNC:1077',
#    'OMIM:603248',
#    'IUPHAR:1789'],
#   'Genatlas': 'BMPR1B',
#   'Ensembl': 'ENSG00000138696',
#   'Reactome': 'O00238',
#   'SwissProt': 'O00238',
#   'HGNC': '1077',
#   'OMIM': '603248',
#   'IUPHAR': '1789'},
#  {'GARD_ID': 1300,
#   'GARD_Disease': 'Chondrodysplasia, Grebe type',
#   'Disease_Gene_Association': 'Disease-causing germline mutation(s) (loss of function) in',
#   'Gene_Symbol': 'GDF5',
#   'Gene_Name': 'growth differentiation factor 5',
#   'Gene_Refs': ['Reactome:P43026',
#    'HGNC:4220',
#    'Ensembl:ENSG00000125965',
#    'OMIM:601146',
#    'Genatlas:GDF5',
#    'SwissProt:P43026'],
#   'Reactome': 'P43026',
#   'HGNC': '4220',
#   'Ensembl': 'ENSG00000125965',
#   'OMIM': '601146',
#   'Genatlas': 'GDF5',
#   'SwissProt': 'P43026'},
#  {'GARD_ID': 1301,
#   'GARD_Disease': 'Ellis-Van Creveld syndrome',
#   'Disease_Gene_Association': 'Disease-causing germline mutation(s) in',
#   'Gene_Symbol': 'DYNC2LI1',
#   'Gene_Name': 'dynein cytoplasmic 2 light intermediate chain 1',
#   'Gene_Refs': ['Ensembl:ENSG00000138036',
#    'Genatlas:DYNC2LI1',
#    'SwissProt:Q8TCX1',
#    'HGNC:24595',
#    'Reactome:Q8TCX1',
#    'OMIM:617083'],
#   'Ensembl': 'ENSG00000138036',
#   'Genatlas': 'DYNC2LI1',
#   'SwissProt': 'Q8TCX1',
#   'HGNC': '24595',
#   'Reactome': 'Q8TCX1',
#   'OMIM': '617083'},
#  {'GARD_ID': 1301,
#   'GARD_Disease': 'Ellis-Van Creveld syndrome',
#   'Disease_Gene_Association': 'Disease-causing germline mutation(s) (loss of function) in',
#   'Gene_Symbol': 'GLI1',
#   'Gene_Name': 'GLI family zinc finger 1',
#   'Gene_Refs': ['Genatlas:GLI1',
#    'Reactome:P08151',
#    'SwissProt:P08151',
#    'HGNC:4317',
#    'Ensembl:ENSG00000111087',
#    'OMIM:165220'],
#   'Genatlas': 'GLI1',
#   'Reactome': 'P08151',
#   'SwissProt': 'P08151',
#   'HGNC': '4317',
#   'Ensembl': 'ENSG00000111087',
#   'OMIM': '165220'},
#  {'GARD_ID': 1301,
#   'GARD_Disease': 'Ellis-Van Creveld syndrome',
#   'Disease_Gene_Association': 'Disease-causing germline mutation(s) in',
#   'Gene_Symbol': 'EVC',
#   'Gene_Name': 'EvC ciliary complex subunit 1',
#   'Gene_Refs': ['SwissProt:P57679',
#    'Ensembl:ENSG00000072840',
#    'HGNC:3497',
#    'Genatlas:EVC',
#    'OMIM:604831',
#    'Reactome:P57679'],
#   'SwissProt': 'P57679',
#   'Ensembl': 'ENSG00000072840',
#   'HGNC': '3497',
#   'Genatlas': 'EVC',
#   'OMIM': '604831',
#   'Reactome': 'P57679'},
#  {'GARD_ID': 1301,
#   'GARD_Disease': 'Ellis-Van Creveld syndrome',
#   'Disease_Gene_Association': 'Disease-causing germline mutation(s) in',
#   'Gene_Symbol': 'EVC2',
#   'Gene_Name': 'EvC ciliary complex subunit 2',
#   'Gene_Refs': ['SwissProt:Q86UK5',
#    'Genatlas:EVC2',
#    'OMIM:607261',
#    'Ensembl:ENSG00000173040',
#    'Reactome:Q86UK5',
#    'HGNC:19747'],
#   'SwissProt': 'Q86UK5',
#   'Genatlas': 'EVC2',
#   'OMIM': '607261',
#   'Ensembl': 'ENSG00000173040',
#   'Reactome': 'Q86UK5',
#   'HGNC': '19747'},
#  {'GARD_ID': 1303,
#   'GARD_Disease': 'Chordoma',
#   'Disease_Gene_Association': 'Major susceptibility factor in',
#   'Gene_Symbol': 'TBXT',
#   'Gene_Name': 'T-box transcription factor T',
#   'Gene_Refs': ['Genatlas:T',
#    'OMIM:601397',
#    'SwissProt:O15178',
#    'HGNC:11515',
#    'Ensembl:ENSG00000164458'],
#   'Genatlas': 'T',
#   'OMIM': '601397',
#   'SwissProt': 'O15178',
#   'HGNC': '11515',
#   'Ensembl': 'ENSG00000164458'},
#  {'GARD_ID': 1305,
#   'GARD_Disease': 'Benign hereditary chorea',
#   'Disease_Gene_Association': None,
#   'Gene_Symbol': None,
#   'Gene_Name': None,
#   'Gene_Refs': None},
#  {'GARD_ID': 1306,
#   'GARD_Disease': 'Choreoacanthocytosis amyotrophic',
#   'Disease_Gene_Association': None,
#   'Gene_Symbol': None,
#   'Gene_Name': None,
#   'Gene_Refs': None},
#  {'GARD_ID': 1309,
#   'GARD_Disease': 'Choroid plexus cyst',
#   'Disease_Gene_Association': None,
#   'Gene_Symbol': None,
#   'Gene_Name': None,
#   'Gene_Refs': None},
#  {'GARD_ID': 1312,
#   'GARD_Disease': 'Choroideremia hypopituitarism',
#   'Disease_Gene_Association': None,
#   'Gene_Symbol': None,
#   'Gene_Name': None,
#   'Gene_Refs': None},
#  {'GARD_ID': 1313,
#   'GARD_Disease': 'Infantile choroidocerebral calcification syndrome',
#   'Disease_Gene_Association': None,
#   'Gene_Symbol': None,
#   'Gene_Name': None,
#   'Gene_Refs': None},
#  {'GARD_ID': 1315,
#   'GARD_Disease': 'Christian Demyer Franken syndrome',
#   'Disease_Gene_Association': None,
#   'Gene_Symbol': None,
#   'Gene_Name': None,
#   'Gene_Refs': None},
#  {'GARD_ID': 1316,
#   'GARD_Disease': 'Christian Johnson Angenieta syndrome',
#   'Disease_Gene_Association': None,
#   'Gene_Symbol': None,
#   'Gene_Name': None,
#   'Gene_Refs': None},
#  {'GARD_ID': 1319,
#   'GARD_Disease': 'Chromoblastomycosis',
#   'Disease_Gene_Association': None,
#   'Gene_Symbol': None,
#   'Gene_Name': None,
#   'Gene_Refs': None},
#  {'GARD_ID': 1320,
#   'GARD_Disease': 'Ring chromosome 1',
#   'Disease_Gene_Association': None,
#   'Gene_Symbol': None,
#   'Gene_Name': None,
#   'Gene_Refs': None},
#  {'GARD_ID': 1322,
#   'GARD_Disease': 'Ring chromosome 10',
#   'Disease_Gene_Association': None,
#   'Gene_Symbol': None,
#   'Gene_Name': None,
#   'Gene_Refs': None},
#  {'GARD_ID': 1323,
#   'GARD_Disease': 'Chromosome 10p deletion',
#   'Disease_Gene_Association': None,
#   'Gene_Symbol': None,
#   'Gene_Name': None,
#   'Gene_Refs': None},
#  {'GARD_ID': 1325,
#   'GARD_Disease': 'Ring chromosome 12',
#   'Disease_Gene_Association': None,
#   'Gene_Symbol': None,
#   'Gene_Name': None,
#   'Gene_Refs': None},
#  {'GARD_ID': 1327,
#   'GARD_Disease': 'Mosaic trisomy 14',
#   'Disease_Gene_Association': None,
#   'Gene_Symbol': None,
#   'Gene_Name': None,
#   'Gene_Refs': None},
#  {'GARD_ID': 1328,
#   'GARD_Disease': 'Ring chromosome 15',
#   'Disease_Gene_Association': None,
#   'Gene_Symbol': None,
#   'Gene_Name': None,
#   'Gene_Refs': None},
#  {'GARD_ID': 1333,
#   'GARD_Disease': 'Ring chromosome 19',
#   'Disease_Gene_Association': None,
#   'Gene_Symbol': None,
#   'Gene_Name': None,
#   'Gene_Refs': None},
#  {'GARD_ID': 1334,
#   'GARD_Disease': 'Ring chromosome 20',
#   'Disease_Gene_Association': None,
#   'Gene_Symbol': None,
#   'Gene_Name': None,
#   'Gene_Refs': None},
#  {'GARD_ID': 1336,
#   'GARD_Disease': 'Ring chromosome 22',
#   'Disease_Gene_Association': None,
#   'Gene_Symbol': None,
#   'Gene_Name': None,
#   'Gene_Refs': None},
#  {'GARD_ID': 1339,
#   'GARD_Disease': 'Ring chromosome 4',
#   'Disease_Gene_Association': None,
#   'Gene_Symbol': None,
#   'Gene_Name': None,
#   'Gene_Refs': None},
#  {'GARD_ID': 1340,
#   'GARD_Disease': 'Chromosome 4q deletion',
#   'Disease_Gene_Association': None,
#   'Gene_Symbol': None,
#   'Gene_Name': None,
#   'Gene_Refs': None},
#  {'GARD_ID': 1345,
#   'GARD_Disease': 'Ring chromosome 7',
#   'Disease_Gene_Association': None,
#   'Gene_Symbol': None,
#   'Gene_Name': None,
#   'Gene_Refs': None},
#  {'GARD_ID': 1346,
#   'GARD_Disease': 'Chromosome 7p deletion',
#   'Disease_Gene_Association': None,
#   'Gene_Symbol': None,
#   'Gene_Name': None,
#   'Gene_Refs': None},
#  {'GARD_ID': 1347,
#   'GARD_Disease': 'Ring chromosome 8',
#   'Disease_Gene_Association': None,
#   'Gene_Symbol': None,
#   'Gene_Name': None,
#   'Gene_Refs': None},
#  {'GARD_ID': 1348,
#   'GARD_Disease': 'Ring chromosome 9',
#   'Disease_Gene_Association': None,
#   'Gene_Symbol': None,
#   'Gene_Name': None,
#   'Gene_Refs': None},
#  {'GARD_ID': 1352,
#   'GARD_Disease': 'Chronic demyelinizing neuropathy with IgM monoclonal',
#   'Disease_Gene_Association': None,
#   'Gene_Symbol': None,
#   'Gene_Name': None,
#   'Gene_Refs': None},
#  {'GARD_ID': 1355,
#   'GARD_Disease': 'Chronic polyradiculoneuritis',
#   'Disease_Gene_Association': None,
#   'Gene_Symbol': None,
#   'Gene_Name': None,
#   'Gene_Refs': None},
#  {'GARD_ID': 1356,
#   'GARD_Disease': 'Neonatal Onset Multisystem Inflammatory disease',
#   'Disease_Gene_Association': 'Candidate gene tested in',
#   'Gene_Symbol': 'NLRC4',
#   'Gene_Name': 'NLR family CARD domain containing 4',
#   'Gene_Refs': ['Reactome:Q9NPP4',
#    'OMIM:606831',
#    'Genatlas:NLRC4',
#    'SwissProt:Q9NPP4',
#    'HGNC:16412',
#    'Ensembl:ENSG00000091106',
#    'IUPHAR:1782'],
#   'Reactome': 'Q9NPP4',
#   'OMIM': '606831',
#   'Genatlas': 'NLRC4',
#   'SwissProt': 'Q9NPP4',
#   'HGNC': '16412',
#   'Ensembl': 'ENSG00000091106',
#   'IUPHAR': '1782'},
#  {'GARD_ID': 1356,
#   'GARD_Disease': 'Neonatal Onset Multisystem Inflammatory disease',
#   'Disease_Gene_Association': 'Disease-causing germline mutation(s) in',
#   'Gene_Symbol': 'NLRP3',
#   'Gene_Name': 'NLR family pyrin domain containing 3',
#   'Gene_Refs': ['OMIM:606416',
#    'Reactome:Q96P20',
#    'HGNC:16400',
#    'SwissProt:Q96P20',
#    'Ensembl:ENSG00000162711',
#    'Genatlas:NLRP3'],
#   'OMIM': '606416',
#   'Reactome': 'Q96P20',
#   'HGNC': '16400',
#   'SwissProt': 'Q96P20',
#   'Ensembl': 'ENSG00000162711',
#   'Genatlas': 'NLRP3'},
#  {'GARD_ID': 1358,
#   'GARD_Disease': 'Chudley Rozdilsky syndrome',
#   'Disease_Gene_Association': None,
#   'Gene_Symbol': None,
#   'Gene_Name': None,
#   'Gene_Refs': None},
#  {'GARD_ID': 1359,
#   'GARD_Disease': 'Chylous ascites',
#   'Disease_Gene_Association': None,
#   'Gene_Symbol': None,
#   'Gene_Name': None,
#   'Gene_Refs': None},
#  {'GARD_ID': 1360,
#   'GARD_Disease': 'Ciliary discoordination, due to random ciliary orientation',
#   'Disease_Gene_Association': None,
#   'Gene_Symbol': None,
#   'Gene_Name': None,
#   'Gene_Refs': None},
#  {'GARD_ID': 1361,
#   'GARD_Disease': 'Ciliary dyskinesia, due to transposition of ciliary microtubules',
#   'Disease_Gene_Association': None,
#   'Gene_Symbol': None,
#   'Gene_Name': None,
#   'Gene_Refs': None},
#  {'GARD_ID': 1362,
#   'GARD_Disease': 'Ciliary dyskinesia-bronchiectasis',
#   'Disease_Gene_Association': None,
#   'Gene_Symbol': None,
#   'Gene_Name': None,
#   'Gene_Refs': None},
#  {'GARD_ID': 1365,
#   'GARD_Disease': 'Circumscribed cutaneous aplasia of the vertex',
#   'Disease_Gene_Association': None,
#   'Gene_Symbol': None,
#   'Gene_Name': None,
#   'Gene_Refs': None},
#  {'GARD_ID': 1366,
#   'GARD_Disease': 'Circumscribed disseminated keratosis Jadassohn Lew type',
#   'Disease_Gene_Association': None,
#   'Gene_Symbol': None,
#   'Gene_Name': None,
#   'Gene_Refs': None},
#  ...]

# %%
gard_gene_df = pd.DataFrame(gard_gene_data)
gard_gene_df
# Out:
#       GARD_ID                                       GARD_Disease  \
# 0           1                                   GRACILE syndrome
# 1           3                    Ablepharon macrostomia syndrome
# 2           4                              Acanthocheilonemiasis
# 3           5                               Abetalipoproteinemia
# 4           6                            Acromesomelic dysplasia
# ...       ...                                                ...
# 7790    13390                       12q14 microdeletion syndrome
# 7791    13390                       12q14 microdeletion syndrome
# 7792    13391                   2p15p16.1 microdeletion syndrome
# 7793    13392                 16p13.11 microduplication syndrome
# 7794    13423  TANGO2-Related Metabolic Encephalopathy and Ar...
#
#                      Disease_Gene_Association Gene_Symbol  \
# 0     Disease-causing germline mutation(s) in       BCS1L
# 1     Disease-causing germline mutation(s) in      TWIST2
# 2                                        None        None
# 3     Disease-causing germline mutation(s) in        MTTP
# 4                                        None        None
# ...                                       ...         ...
# 7790                 Role in the phenotype of       LEMD3
# 7791                 Role in the phenotype of       HMGA2
# 7792                                     None        None
# 7793                                     None        None
# 7794                                     None        None
#
#                                               Gene_Name  \
# 0     BCS1 homolog, ubiquinol-cytochrome c reductase...
# 1              twist family bHLH transcription factor 2
# 2                                                  None
# 3              microsomal triglyceride transfer protein
# 4                                                  None
# ...                                                 ...
# 7790                            LEM domain containing 3
# 7791                      high mobility group AT-hook 2
# 7792                                               None
# 7793                                               None
# 7794                                               None
#
#                                               Gene_Refs    OMIM  \
# 0     [OMIM:603647, Ensembl:ENSG00000074582, Genatla...  603647
# 1     [Ensembl:ENSG00000233608, OMIM:607556, Reactom...  607556
# 2                                                  None     NaN
# 3     [Ensembl:ENSG00000138823, Genatlas:MTTP, React...  157147
# 4                                                  None     NaN
# ...                                                 ...     ...
# 7790  [Reactome:Q9Y2U8, SwissProt:Q9Y2U8, OMIM:60784...  607844
# 7791  [SwissProt:P52926, Reactome:P52926, HGNC:5009,...  600698
# 7792                                               None     NaN
# 7793                                               None     NaN
# 7794                                               None     NaN
#
#               Ensembl Genatlas SwissProt   HGNC Reactome IUPHAR
# 0     ENSG00000074582    BCS1L    Q9Y276   1020   Q9Y276    NaN
# 1     ENSG00000233608   TWIST2    Q8WVJ9  20670   Q8WVJ9    NaN
# 2                 NaN      NaN       NaN    NaN      NaN    NaN
# 3     ENSG00000138823     MTTP    P55157   7467   P55157    NaN
# 4                 NaN      NaN       NaN    NaN      NaN    NaN
# ...               ...      ...       ...    ...      ...    ...
# 7790  ENSG00000174106    LEMD3    Q9Y2U8  28887   Q9Y2U8    NaN
# 7791  ENSG00000149948    HMGA2    P52926   5009   P52926    NaN
# 7792              NaN      NaN       NaN    NaN      NaN    NaN
# 7793              NaN      NaN       NaN    NaN      NaN    NaN
# 7794              NaN      NaN       NaN    NaN      NaN    NaN
#
# [7795 rows x 13 columns]

# %%
len(set(gard_gene_df[(gard_gene_df['Gene_Symbol'].isnull() == False)].GARD_ID))
# Out:
# 2009

# %%
gard_symbol_hgnc = gard_gene_df[(gard_gene_df['Gene_Symbol'].isnull() == False) & 
             (gard_gene_df['HGNC'].isnull() == False)][['Gene_Symbol','HGNC']].drop_duplicates()

#Some dictionaries for convenient mapping later
sym2hgnc = {row['Gene_Symbol']:row['HGNC'] for i,row in gard_symbol_hgnc.iterrows()}
hgnc2sym = {row['HGNC']:row['Gene_Symbol'] for i,row in gard_symbol_hgnc.iterrows()}

# %%
#Use MyGene.info, part of biothings, to get NCBI id's
#So we can use NCBI go annotationsS
mg = mygene.MyGeneInfo()
mg_hgnc = mg.querymany([i for i in gard_symbol_hgnc['HGNC']], scopes='hgnc', fields='entrezgene', species='human')
hgnc2ncbi = {i.get('query') : i.get('entrezgene') for i in mg_hgnc if i.get('entrezgene') is not None}
# Out:
# querying 1-1000...done.
# querying 1001-2000...done.
# querying 2001-2730...done.
# Finished.
# 18 input query terms found no hit:
# 	['21340', '3777', '33445', '43724', '12599', '22433', '31376', '22993', '25855', '14260', '16706', '
# Pass "returnall=True" to return complete lists of duplicate or missing query terms.

# %%
len(hgnc2ncbi)
# Out:
# 2712

# %%
no_hgnc_hits = gard_symbol_hgnc[(gard_symbol_hgnc['HGNC'].isin(hgnc2ncbi.keys())==False)]

# %%
mg_symbol = mg.querymany([i for i in no_hgnc_hits['Gene_Symbol']], scopes='symbol', fields='entrezgene', species='human')
# Out:
# querying 1-18...done.
# Finished.
# 2 input query terms found no hit:
# 	['SPG23', 'FMR3']
# Pass "returnall=True" to return complete lists of duplicate or missing query terms.

# %%
hgnc2ncbi.update({sym2hgnc.get(i.get('query')) : i.get('entrezgene') for i in mg_symbol if i.get('entrezgene') is not None})

# %%
len(hgnc2ncbi)
# Out:
# 2728

# %%
sym2ncbi = {hgnc2sym[i]:hgnc2ncbi[i] for i in hgnc2ncbi.keys()}
sym_hits = sym2ncbi.keys()

# %%
#Search by symbol for those where HGNC returned nothing
mg_symbol = mg.querymany(
list(gard_gene_df[(gard_gene_df['Gene_Symbol'].isnull()==False) &
             (gard_gene_df['Gene_Symbol'].isin(sym_hits)==False)]['Gene_Symbol']), 
    scopes='symbol', fields='entrezgene', species='human')
# Out:
# querying 1-4...done.
# Finished.
# 3 input query terms found no hit:
# 	['SPG23', 'FMR3', 'DHS6S1']
# Pass "returnall=True" to return complete lists of duplicate or missing query terms.

# %%
sym2ncbi.update({i.get('query') : i.get('entrezgene') for i in mg_symbol if i.get('entrezgene') is not None})

# %%
ncbi2sym = {sym2ncbi.get(i):i for i in sym2ncbi.keys()}

# %%
#These three genes have not NCBI ID based on search via gene symbol or HGNC id
sym_hits = sym2ncbi.keys()

gard_gene_df[(gard_gene_df['Gene_Symbol'].isnull()==False) &
             (gard_gene_df['Gene_Symbol'].isin(sym_hits)==False)]
# Out:
#       GARD_ID                      GARD_Disease  \
# 288       336             Spastic paraplegia 23
# 1647     2378               Fragile XE syndrome
# 5418     9179  North Carolina macular dystrophy
#
#                      Disease_Gene_Association Gene_Symbol  \
# 288   Disease-causing germline mutation(s) in       SPG23
# 1647  Disease-causing germline mutation(s) in        FMR3
# 5418  Disease-causing germline mutation(s) in      DHS6S1
#
#                                           Gene_Name  \
# 288     spastic paraplegia 23 (autosomal recessive)
# 1647      fragile X mental retardation associated 3
# 5418  DNase1 hypersensitivity, chromosome 6, site 1
#
#                        Gene_Refs    OMIM Ensembl Genatlas SwissProt   HGNC  \
# 288                 [HGNC:21340]     NaN     NaN      NaN       NaN  21340
# 1647  [HGNC:3777, Genatlas:FMR3]     NaN     NaN     FMR3       NaN   3777
# 5418               [OMIM:616842]  616842     NaN      NaN       NaN    NaN
#
#      Reactome IUPHAR
# 288       NaN    NaN
# 1647      NaN    NaN
# 5418      NaN    NaN

# %% [markdown]
# ### Gene Ontology and annotations

# %% [markdown]
# We obtain the gene onotlogy from the obolibrary, this has the the full GO dag.
#
# Then we need annotations that link genes to GO terms. We explore two resources for this:
#
# * The EBI curated gaf file, provided by geneonoloty.org
# * The NCBI curate gene2go file, obtained using GOAtools

# %%
gene_ontology = from_file("http://purl.obolibrary.org/obo/go.owl")
gene_ontology.graph.nodes.get('GO:0003723')
# Out:
# /Users/sanjakjs/opt/anaconda3/envs/ontograph/lib/python3.8/site-packages/pronto/parsers/rdfxml.py:286: SyntaxWarning: <Element '{http://purl.org/dc/elements/1.1/}description' at 0x7ff3c8a46180> contains text but no `xsd:datatype`
#   meta.annotations.add(self._extract_literal_pv(child))
# /Users/sanjakjs/opt/anaconda3/envs/ontograph/lib/python3.8/site-packages/pronto/parsers/rdfxml.py:286: SyntaxWarning: <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7ff3c8a46220> contains text but no `xsd:datatype`
#   meta.annotations.add(self._extract_literal_pv(child))
# /Users/sanjakjs/opt/anaconda3/envs/ontograph/lib/python3.8/site-packages/pronto/parsers/rdfxml.py:286: SyntaxWarning: <Element '{http://www.w3.org/2002/07/owl#}versionInfo' at 0x7ff3c8a46400> contains text but no `xsd:datatype`
#   meta.annotations.add(self._extract_literal_pv(child))
# /Users/sanjakjs/opt/anaconda3/envs/ontograph/lib/python3.8/site-packages/pronto/parsers/rdfxml.py:113: SyntaxWarning: unknown element in `owl:ObjectProperty`: <Element '{http://www.w3.org/2002/07/owl#}propertyChainAxiom' at 0x7ff398fdd860>
#   self._extract_object_property(prop, curies)
# /Users/sanjakjs/opt/anaconda3/envs/ontograph/lib/python3.8/site-packages/pronto/parsers/rdfxml.py:113: SyntaxWarning: unknown element in `owl:ObjectProperty`: <Element '{http://www.w3.org/2002/07/owl#}propertyChainAxiom' at 0x7ff398fe3770>
#   self._extract_object_property(prop, curies)
# /Users/sanjakjs/opt/anaconda3/envs/ontograph/lib/python3.8/site-packages/pronto/ontology.py:283: NotImplementedWarning: cannot process plain `owl:AnnotationProperty`
#   cls(self).parse_from(_handle)  # type: ignore
# /Users/sanjakjs/opt/anaconda3/envs/ontograph/lib/python3.8/site-packages/pronto/ontology.py:283: SyntaxWarning: could not extract ID from `oboInOwl:consider` annotation
#   cls(self).parse_from(_handle)  # type: ignore
# /Users/sanjakjs/opt/anaconda3/envs/ontograph/lib/python3.8/site-packages/pronto/parsers/rdfxml.py:117: SyntaxWarning: unknown element in `owl:Class`: {http://www.w3.org/2002/07/owl#}equivalentClass
#   self._extract_term(class_, curies)
# /Users/sanjakjs/opt/anaconda3/envs/ontograph/lib/python3.8/site-packages/pronto/parsers/rdfxml.py:117: SyntaxWarning: could not extract ID from `IAO:0100001` annotation
#   self._extract_term(class_, curies)
# /Users/sanjakjs/opt/anaconda3/envs/ontograph/lib/python3.8/site-packages/pronto/parsers/rdfxml.py:117: SyntaxWarning: unknown element in `owl:Class`: {http://purl.obolibrary.org/obo/}IAO_0000589
#   self._extract_term(class_, curies)
# {'identifier': 'GO:0003723',
#  'label': 'RNA binding',
#  'namespace': 'molecular_function'}

# %%
#Obtained from http://geneontology.org/gene-associations/goa_human.gaf.gz
gene_annotations = GafReader("goa_human.gaf")
# Out:
# HMS:0:00:12.268476 609,183 annotations READ: goa_human.gaf

# %%
#From NCBI via goatools
fin_gene2go = download_ncbi_associations()

# Read NCBI's gene2go. Store annotations in a list of namedtuples
objanno = Gene2GoReader(fin_gene2go, taxids=[9606])

# Get namespace2association where:
#    namespace is:
#        BP: biological_process               
#        MF: molecular_function
#        CC: cellular_component
#    assocation is a dict:
#        key: NCBI GeneID
#        value: A set of GO IDs associated with that gene
ns2assoc = objanno.get_ns2assc()

for nspc, id2gos in ns2assoc.items():
    print("{NS} {N:,} annotated mouse genes".format(NS=nspc, N=len(id2gos)))
# Out:
#   EXISTS: gene2go
# HMS:0:00:04.967049 330,404 annotations, 20,688 genes, 18,642 GOs, 1 taxids READ: gene2go
# CC 19,433 annotated mouse genes
# BP 18,501 annotated mouse genes
# MF 18,194 annotated mouse genes

# %%
#NCBI ID to GO mappings from NCBI gene2go table
ncbi2go = {}
for assoc in objanno.associations:
    if assoc.DB_ID in ncbi2go:
        if assoc.NS in ncbi2go[assoc.DB_ID]:
            ncbi2go[assoc.DB_ID][assoc.NS].append({'GO_ID':assoc.GO_ID,'Qualifier':assoc.Qualifier})
        else:
            ncbi2go[assoc.DB_ID][assoc.NS] = [{'GO_ID':assoc.GO_ID,'Qualifier':assoc.Qualifier}]
    else:
        ncbi2go[assoc.DB_ID] = {assoc.NS:[{'GO_ID':assoc.GO_ID,'Qualifier':assoc.Qualifier}]}

# %%
#36 genes have no gene ontology annotation in NCBI
ncbi_no_go = set([int(i) for i in sym2ncbi.values()]).difference(set(ncbi2go.keys()))
len(ncbi_no_go)
# Out:
# 36

# %%
#Gene symbol to GO mapppings from geneontology.org GOA table
gene2go = {}
for assoc in gene_annotations.get_associations():
    if assoc.DB_Symbol in gene2go:
        if assoc.NS in gene2go[assoc.DB_Symbol]:
            gene2go[assoc.DB_Symbol][assoc.NS].append({'GO_ID':assoc.GO_ID,'Qualifier':assoc.Qualifier})
        else:
            gene2go[assoc.DB_Symbol][assoc.NS] = [{'GO_ID':assoc.GO_ID,'Qualifier':assoc.Qualifier}]
    else:
        gene2go[assoc.DB_Symbol] = {assoc.NS:[{'GO_ID':assoc.GO_ID,'Qualifier':assoc.Qualifier}]}

# %% [markdown]
# ### Disease to GO through GO annotations

# %%
#How many GARD disease gene symbols have at least one GO annotation?
gard_genes = set(gard_gene_df['Gene_Symbol'][(gard_gene_df['Gene_Symbol'].isnull()==False)])
gard_sym_go = gard_genes.intersection(set(gene2go.keys()))
gard_sym_nogo = gard_genes.difference(set(gene2go.keys()))

#Add additional annotations found through NCBI
gene2go.update({i:ncbi2go[int(sym2ncbi[i])] for i in gard_sym_nogo if i in sym2ncbi and int(sym2ncbi[i]) in ncbi2go})

# %%
#How many GARD disease gene symbols have at least one GO annotation?
gard_genes = set(gard_gene_df['Gene_Symbol'][(gard_gene_df['Gene_Symbol'].isnull()==False)])
gard_sym_go = gard_genes.intersection(set(gene2go.keys()))
gard_sym_nogo = gard_genes.difference(set(gene2go.keys()))

[len(gard_genes), len(gard_sym_go), len(gard_sym_nogo)]
# Out:
# [2732, 2696, 36]

# %% [markdown]
# This shows that the majority, 2696 of 2732, GARD disease associated genes have a GO annotation. What of the remaining 75 gene symbols? There are two obvious reasons for missing GO annotations: a) the gene is truly not annotated in GO by EBI and b) the EBI annotation uses a synonym gene symbol and therefore fails to map to our database. The former issue is not solvable in this context, but the latter may be.

# %% [markdown]
# #### Searching for Gene Symbol aliases

# %%
def gene_alias(hgnc_id):
    """
    This function queries genenames.org for know alias and old gene symbols associated
    with an HGNC ID code.

    Approach taken from https://www.genenames.org/help/rest/
    """
    
    headers = {
    'Accept': 'application/json',
    }

    uri = 'http://rest.genenames.org'
    path = '/fetch/hgnc_id/{0}'.format(hgnc_id)

    target = urllib.parse.urlparse(uri+path)
    method = 'GET'
    body = ''

    h = http.Http()

    response, content = h.request(
        target.geturl(),
        method,
        body,
        headers)

    if response['status'] == '200':
        # assume that content is a json reply
        # parse content with the json module 
        data = json.loads(content)
        if data['response']['numFound'] > 0:
            all_symbols = []
            for sym in ['symbol','prev_symbol','alias_symbol']:
                sym_alias = data['response']['docs'][0].get(sym)
                if sym_alias is not None:
                    if isinstance(sym_alias,list):
                        all_symbols.extend(sym_alias)
                    elif isinstance(sym_alias,str):
                        all_symbols.append(sym_alias)

            return all_symbols
        else:
            return None
    else:
        return None

# %%
symbol_hgnc = gard_gene_df[(gard_gene_df['Gene_Symbol'].isin(gard_sym_nogo)) & 
                           (gard_gene_df['HGNC'].isnull() == False)][['Gene_Symbol','HGNC']].drop_duplicates()

gard_sym_nogo_aliases = {}
for index, row in symbol_hgnc.iterrows():
    row_alias = gene_alias(row['HGNC'])
    if row_alias is not None:
        gard_sym_nogo_aliases[row['Gene_Symbol']] = row_alias

# %%
#We found info for 34/36 of the gene names without GO annotation
len(gard_sym_nogo_aliases.keys())
# Out:
# 34

# %%
#All of these gene names have at least 3 names
Counter([len(i) for i in gard_sym_nogo_aliases])
# Out:
# Counter({9: 1, 5: 24, 6: 5, 3: 1, 4: 2, 7: 1})

# %%
gard_sym_alias_go = {}
for sym_nogo in gard_sym_nogo_aliases.keys():
    for alias_sym in gard_sym_nogo_aliases.get(sym_nogo):
        if alias_sym in gene2go:
            gard_sym_alias_go[sym_nogo] = alias_sym

# %%
#We found GO annotations through aliases for 1 out of the 36 gene name without direct annotation
len(gard_sym_alias_go)
# Out:
# 1

# %%
gard_sym_alias_go
# Out:
# {'MT-TP': 'MTTP'}

# %% [markdown]
# ### Update the gene to GO annotations via aliases

# %%
for gard_sym in gard_sym_alias_go.keys():
    gene2go[gard_sym] = gene2go[gard_sym_alias_go[gard_sym]]

# %%
#Update to how many GARD disease gene symbols have at least one GO annotation?
gard_sym_go = gard_genes.intersection(set(gene2go.keys()))
gard_sym_nogo = gard_genes.difference(set(gene2go.keys()))

[len(gard_genes), len(gard_sym_go), len(gard_sym_nogo)]
# Out:
# [2732, 2697, 35]

# %% [markdown]
# ##### We still have 35 GARD gene symbols without GO Annotations. More could be mapped by accessing the Uniprot ID's from HGNC and finding GOA's that way. The remaining could be followed up with manually to see if there is an issue.

# %%
gard_gene_df[gard_gene_df['Gene_Symbol'].isin(gard_sym_nogo)]
# Out:
#       GARD_ID                                       GARD_Disease  \
# 288       336                              Spastic paraplegia 23
# 663       848                                     Behçet disease
# 1231     1709  Deafness, isolated, due to mitochondrial trans...
# 1232     1709  Deafness, isolated, due to mitochondrial trans...
# 1340     1839               Transient neonatal diabetes mellitus
# 1634     2356                                Follicular lymphoma
# 1647     2378                                Fragile XE syndrome
# 2003     3094                  Keratoderma palmoplantar deafness
# 2332     3671        Mitochondrial DNA-associated Leigh syndrome
# 2333     3671        Mitochondrial DNA-associated Leigh syndrome
# 2334     3671        Mitochondrial DNA-associated Leigh syndrome
# 2335     3671        Mitochondrial DNA-associated Leigh syndrome
# 2432     3881               Mitochondrial myopathy with diabetes
# 2517     4003         Maternally inherited diabetes and deafness
# 2518     4003         Maternally inherited diabetes and deafness
# 2519     4003         Maternally inherited diabetes and deafness
# 3040     4950                          Spinocerebellar ataxia 30
# 3253     5435                             Usher syndrome, type 1
# 3259     5435                             Usher syndrome, type 1
# 3260     5435                             Usher syndrome, type 1
# 3263     5436                            Usher syndrome, type 1B
# 3269     5436                            Usher syndrome, type 1B
# 3270     5436                            Usher syndrome, type 1B
# 3280     5442                             Usher syndrome type 3A
# 3963     6339                        Endometrial stromal sarcoma
# 3964     6339                        Endometrial stromal sarcoma
# 4064     6485                                   Gastric lymphoma
# 4306     6817                              Kearns-Sayre syndrome
# 4422     6969                               Mantle cell lymphoma
# 4442     7009  Mitochondrial encephalomyopathy lactic acidosi...
# 4450     7009  Mitochondrial encephalomyopathy lactic acidosi...
# 4451     7009  Mitochondrial encephalomyopathy lactic acidosi...
# 4452     7009  Mitochondrial encephalomyopathy lactic acidosi...
# 4453     7009  Mitochondrial encephalomyopathy lactic acidosi...
# 4454     7009  Mitochondrial encephalomyopathy lactic acidosi...
# 4455     7009  Mitochondrial encephalomyopathy lactic acidosi...
# 4505     7139                                 Myoclonus-dystonia
# 4512     7144          Myoclonic epilepsy with ragged red fibers
# 4513     7144          Myoclonic epilepsy with ragged red fibers
# 4515     7144          Myoclonic epilepsy with ragged red fibers
# 4516     7144          Myoclonic epilepsy with ragged red fibers
# 4517     7144          Myoclonic epilepsy with ragged red fibers
# 4518     7144          Myoclonic epilepsy with ragged red fibers
# 4519     7144          Myoclonic epilepsy with ragged red fibers
# 5155     8528                                     HELLP syndrome
# 5418     9179                   North Carolina macular dystrophy
# 5521     9296                              Spastic paraplegia 24
# 5713     9582                              Spastic paraplegia 25
# 5716     9585                              Spastic paraplegia 16
# 5719     9588                              Spastic paraplegia 19
# 5720     9589                              Spastic paraplegia 14
# 5843     9729                              Spastic paraplegia 29
# 6111     9996                          Spinocerebellar ataxia 25
# 6112     9997                          Spinocerebellar ataxia 20
# 6294    10199                                    Optic atrophy 2
# 7340    12368                          Spinocerebellar ataxia 37
# 7548    12749                              Spastic paraplegia 32
#
#                      Disease_Gene_Association Gene_Symbol  \
# 288   Disease-causing germline mutation(s) in       SPG23
# 663            Major susceptibility factor in   IL12A-AS1
# 1231  Disease-causing germline mutation(s) in       MT-TH
# 1232  Disease-causing germline mutation(s) in      MT-TS1
# 1340  Disease-causing germline mutation(s) in       HYMAI
# 1634                 Part of a fusion gene in         IGH
# 1647  Disease-causing germline mutation(s) in        FMR3
# 2003  Disease-causing germline mutation(s) in      MT-TS1
# 2332  Disease-causing germline mutation(s) in      MT-TL1
# 2333  Disease-causing germline mutation(s) in       MT-TK
# 2334  Disease-causing germline mutation(s) in       MT-TW
# 2335  Disease-causing germline mutation(s) in       MT-TV
# 2432  Disease-causing germline mutation(s) in       MT-TE
# 2517  Disease-causing germline mutation(s) in       MT-TE
# 2518  Disease-causing germline mutation(s) in      MT-TL1
# 2519  Disease-causing germline mutation(s) in       MT-TK
# 3040  Disease-causing germline mutation(s) in       SCA30
# 3253  Disease-causing germline mutation(s) in       USH1K
# 3259  Disease-causing germline mutation(s) in       USH1E
# 3260  Disease-causing germline mutation(s) in       USH1H
# 3263  Disease-causing germline mutation(s) in       USH1K
# 3269  Disease-causing germline mutation(s) in       USH1E
# 3270  Disease-causing germline mutation(s) in       USH1H
# 3280  Disease-causing germline mutation(s) in      MT-TS2
# 3963                 Part of a fusion gene in      NUTM2B
# 3964                 Part of a fusion gene in      NUTM2A
# 4064                 Part of a fusion gene in         IGH
# 4306                 Candidate gene tested in      MT-TL1
# 4422   Disease-causing somatic mutation(s) in         IGH
# 4442                 Candidate gene tested in       MT-TQ
# 4450  Disease-causing germline mutation(s) in      MT-TL1
# 4451  Disease-causing germline mutation(s) in       MT-TW
# 4452                 Candidate gene tested in       MT-TH
# 4453  Disease-causing germline mutation(s) in      MT-TS1
# 4454                 Candidate gene tested in      MT-TS2
# 4455  Disease-causing germline mutation(s) in       MT-TF
# 4505                 Role in the phenotype of       DYT15
# 4512  Disease-causing germline mutation(s) in      MT-TL1
# 4513  Disease-causing germline mutation(s) in       MT-TK
# 4515                 Candidate gene tested in       MT-TQ
# 4516  Disease-causing germline mutation(s) in       MT-TH
# 4517  Disease-causing germline mutation(s) in      MT-TS1
# 4518                 Candidate gene tested in      MT-TS2
# 4519  Disease-causing germline mutation(s) in       MT-TF
# 5155           Major susceptibility factor in     HELLPAR
# 5418  Disease-causing germline mutation(s) in      DHS6S1
# 5521  Disease-causing germline mutation(s) in       SPG24
# 5713  Disease-causing germline mutation(s) in       SPG25
# 5716  Disease-causing germline mutation(s) in       SPG16
# 5719  Disease-causing germline mutation(s) in       SPG19
# 5720  Disease-causing germline mutation(s) in       SPG14
# 5843  Disease-causing germline mutation(s) in       SPG29
# 6111  Disease-causing germline mutation(s) in       SCA25
# 6112  Disease-causing germline mutation(s) in       SCA20
# 6294  Disease-causing germline mutation(s) in        OPA2
# 7340  Disease-causing germline mutation(s) in       SCA37
# 7548  Disease-causing germline mutation(s) in       SPG32
#
#                                               Gene_Name  \
# 288         spastic paraplegia 23 (autosomal recessive)
# 663                               IL12A antisense RNA 1
# 1231           mitochondrially encoded tRNA-His (CAU/C)
# 1232           mitochondrially encoded tRNA-Ser (UCN) 1
# 1340         hydatidiform mole associated and imprinted
# 1634                         immunoglobulin heavy locus
# 1647          fragile X mental retardation associated 3
# 2003           mitochondrially encoded tRNA-Ser (UCN) 1
# 2332         mitochondrially encoded tRNA-Leu (UUA/G) 1
# 2333           mitochondrially encoded tRNA-Lys (AAA/G)
# 2334           mitochondrially encoded tRNA-Trp (UGA/G)
# 2335             mitochondrially encoded tRNA-Val (GUN)
# 2432           mitochondrially encoded tRNA-Glu (GAA/G)
# 2517           mitochondrially encoded tRNA-Glu (GAA/G)
# 2518         mitochondrially encoded tRNA-Leu (UUA/G) 1
# 2519           mitochondrially encoded tRNA-Lys (AAA/G)
# 3040                          spinocerebellar ataxia 30
# 3253            Usher syndrome 1K (autosomal recessive)
# 3259    Usher syndrome 1E (autosomal recessive, severe)
# 3260            Usher syndrome 1H (autosomal recessive)
# 3263            Usher syndrome 1K (autosomal recessive)
# 3269    Usher syndrome 1E (autosomal recessive, severe)
# 3270            Usher syndrome 1H (autosomal recessive)
# 3280         mitochondrially encoded tRNA-Ser (AGU/C) 2
# 3963                               NUT family member 2B
# 3964                               NUT family member 2A
# 4064                         immunoglobulin heavy locus
# 4306         mitochondrially encoded tRNA-Leu (UUA/G) 1
# 4422                         immunoglobulin heavy locus
# 4442           mitochondrially encoded tRNA-Gln (CAA/G)
# 4450         mitochondrially encoded tRNA-Leu (UUA/G) 1
# 4451           mitochondrially encoded tRNA-Trp (UGA/G)
# 4452           mitochondrially encoded tRNA-His (CAU/C)
# 4453           mitochondrially encoded tRNA-Ser (UCN) 1
# 4454         mitochondrially encoded tRNA-Ser (AGU/C) 2
# 4455           mitochondrially encoded tRNA-Phe (UUU/C)
# 4505                             dystonia 15, myoclonic
# 4512         mitochondrially encoded tRNA-Leu (UUA/G) 1
# 4513           mitochondrially encoded tRNA-Lys (AAA/G)
# 4515           mitochondrially encoded tRNA-Gln (CAA/G)
# 4516           mitochondrially encoded tRNA-His (CAU/C)
# 4517           mitochondrially encoded tRNA-Ser (UCN) 1
# 4518         mitochondrially encoded tRNA-Ser (AGU/C) 2
# 4519           mitochondrially encoded tRNA-Phe (UUU/C)
# 5155               HELLP associated long non-coding RNA
# 5418      DNase1 hypersensitivity, chromosome 6, site 1
# 5521        spastic paraplegia 24 (autosomal recessive)
# 5713  spastic paraplegia 25 (autosomal recessive, wi...
# 5716  spastic paraplegia 16 (complicated, X-linked r...
# 5719         spastic paraplegia 19 (autosomal dominant)
# 5720        spastic paraplegia 14 (autosomal recessive)
# 5843         spastic paraplegia 29 (autosomal dominant)
# 6111                          spinocerebellar ataxia 25
# 6112                          spinocerebellar ataxia 20
# 6294                          optic atrophy 2 (obscure)
# 7340                          spinocerebellar ataxia 37
# 7548        spastic paraplegia 32 (autosomal recessive)
#
#                                               Gene_Refs    OMIM  \
# 288                                        [HGNC:21340]     NaN
# 663               [HGNC:49094, Ensembl:ENSG00000244040]     NaN
# 1231  [OMIM:590040, Genatlas:TRNH, Ensembl:ENSG00000...  590040
# 1232  [HGNC:7497, Ensembl:ENSG00000210151, OMIM:5900...  590080
# 1340  [OMIM:606546, Ensembl:ENSG00000283122, HGNC:53...  606546
# 1634       [HGNC:5477, Genatlas:IGH@, SwissProt:Q6P089]     NaN
# 1647                         [HGNC:3777, Genatlas:FMR3]     NaN
# 2003  [HGNC:7497, Ensembl:ENSG00000210151, OMIM:5900...  590080
# 2332  [Genatlas:MT-TL1, Ensembl:ENSG00000209082, OMI...  590050
# 2333  [OMIM:590060, Ensembl:ENSG00000210156, Genatla...  590060
# 2334  [Genatlas:MT-TW, Ensembl:ENSG00000210117, HGNC...  590095
# 2335  [Ensembl:ENSG00000210077, HGNC:7500, OMIM:5901...  590105
# 2432  [HGNC:7479, Genatlas:MT-TE, Ensembl:ENSG000002...  590025
# 2517  [HGNC:7479, Genatlas:MT-TE, Ensembl:ENSG000002...  590025
# 2518  [Genatlas:MT-TL1, Ensembl:ENSG00000209082, OMI...  590050
# 2519  [OMIM:590060, Ensembl:ENSG00000210156, Genatla...  590060
# 3040                                       [HGNC:33445]     NaN
# 3253                                       [HGNC:43724]     NaN
# 3259                                       [HGNC:12599]     NaN
# 3260                                       [HGNC:22433]     NaN
# 3263                                       [HGNC:43724]     NaN
# 3269                                       [HGNC:12599]     NaN
# 3270                                       [HGNC:22433]     NaN
# 3280  [HGNC:7498, Genatlas:MT-TS2, OMIM:590085, Ense...  590085
# 3963  [Genatlas:FAM22B, SwissProt:A6NNL0, Ensembl:EN...     NaN
# 3964  [HGNC:23438, Genatlas:FAM22A, SwissProt:Q8IVF1...     NaN
# 4064       [HGNC:5477, Genatlas:IGH@, SwissProt:Q6P089]     NaN
# 4306  [Genatlas:MT-TL1, Ensembl:ENSG00000209082, OMI...  590050
# 4422       [HGNC:5477, Genatlas:IGH@, SwissProt:Q6P089]     NaN
# 4442  [OMIM:590030, HGNC:7495, Ensembl:ENSG000002101...  590030
# 4450  [Genatlas:MT-TL1, Ensembl:ENSG00000209082, OMI...  590050
# 4451  [Genatlas:MT-TW, Ensembl:ENSG00000210117, HGNC...  590095
# 4452  [OMIM:590040, Genatlas:TRNH, Ensembl:ENSG00000...  590040
# 4453  [HGNC:7497, Ensembl:ENSG00000210151, OMIM:5900...  590080
# 4454  [HGNC:7498, Genatlas:MT-TS2, OMIM:590085, Ense...  590085
# 4455  [OMIM:590070, HGNC:7481, Ensembl:ENSG000002100...  590070
# 4505                                       [HGNC:31376]     NaN
# 4512  [Genatlas:MT-TL1, Ensembl:ENSG00000209082, OMI...  590050
# 4513  [OMIM:590060, Ensembl:ENSG00000210156, Genatla...  590060
# 4515  [OMIM:590030, HGNC:7495, Ensembl:ENSG000002101...  590030
# 4516  [OMIM:590040, Genatlas:TRNH, Ensembl:ENSG00000...  590040
# 4517  [HGNC:7497, Ensembl:ENSG00000210151, OMIM:5900...  590080
# 4518  [HGNC:7498, Genatlas:MT-TS2, OMIM:590085, Ense...  590085
# 4519  [OMIM:590070, HGNC:7481, Ensembl:ENSG000002100...  590070
# 5155  [HGNC:43984, Ensembl:ENSG00000281344, OMIM:614...  614985
# 5418                                      [OMIM:616842]  616842
# 5521                                       [HGNC:22993]     NaN
# 5713                                       [HGNC:25855]     NaN
# 5716                                       [HGNC:14260]     NaN
# 5719                                       [HGNC:16706]     NaN
# 5720                                       [HGNC:13730]     NaN
# 5843                                       [HGNC:30161]     NaN
# 6111                                       [HGNC:20684]     NaN
# 6112                                       [HGNC:17204]     NaN
# 6294                                        [HGNC:8141]     NaN
# 7340                                       [HGNC:43726]     NaN
# 7548                                       [HGNC:32314]     NaN
#
#               Ensembl Genatlas SwissProt   HGNC Reactome IUPHAR
# 288               NaN      NaN       NaN  21340      NaN    NaN
# 663   ENSG00000244040      NaN       NaN  49094      NaN    NaN
# 1231  ENSG00000210176     TRNH       NaN   7487      NaN    NaN
# 1232  ENSG00000210151   MT-TS1       NaN   7497      NaN    NaN
# 1340  ENSG00000283122    HYMAI       NaN   5326      NaN    NaN
# 1634              NaN     IGH@    Q6P089   5477      NaN    NaN
# 1647              NaN     FMR3       NaN   3777      NaN    NaN
# 2003  ENSG00000210151   MT-TS1       NaN   7497      NaN    NaN
# 2332  ENSG00000209082   MT-TL1       NaN   7490      NaN    NaN
# 2333  ENSG00000210156    MT-TK       NaN   7489      NaN    NaN
# 2334  ENSG00000210117    MT-TW       NaN   7501      NaN    NaN
# 2335  ENSG00000210077    MT-TV       NaN   7500      NaN    NaN
# 2432  ENSG00000210194    MT-TE       NaN   7479      NaN    NaN
# 2517  ENSG00000210194    MT-TE       NaN   7479      NaN    NaN
# 2518  ENSG00000209082   MT-TL1       NaN   7490      NaN    NaN
# 2519  ENSG00000210156    MT-TK       NaN   7489      NaN    NaN
# 3040              NaN      NaN       NaN  33445      NaN    NaN
# 3253              NaN      NaN       NaN  43724      NaN    NaN
# 3259              NaN      NaN       NaN  12599      NaN    NaN
# 3260              NaN      NaN       NaN  22433      NaN    NaN
# 3263              NaN      NaN       NaN  43724      NaN    NaN
# 3269              NaN      NaN       NaN  12599      NaN    NaN
# 3270              NaN      NaN       NaN  22433      NaN    NaN
# 3280  ENSG00000210184   MT-TS2       NaN   7498      NaN    NaN
# 3963  ENSG00000188199   FAM22B    A6NNL0  23445      NaN    NaN
# 3964  ENSG00000184923   FAM22A    Q8IVF1  23438      NaN    NaN
# 4064              NaN     IGH@    Q6P089   5477      NaN    NaN
# 4306  ENSG00000209082   MT-TL1       NaN   7490      NaN    NaN
# 4422              NaN     IGH@    Q6P089   5477      NaN    NaN
# 4442  ENSG00000210107    MT-TQ       NaN   7495      NaN    NaN
# 4450  ENSG00000209082   MT-TL1       NaN   7490      NaN    NaN
# 4451  ENSG00000210117    MT-TW       NaN   7501      NaN    NaN
# 4452  ENSG00000210176     TRNH       NaN   7487      NaN    NaN
# 4453  ENSG00000210151   MT-TS1       NaN   7497      NaN    NaN
# 4454  ENSG00000210184   MT-TS2       NaN   7498      NaN    NaN
# 4455  ENSG00000210049    MT-TF       NaN   7481      NaN    NaN
# 4505              NaN      NaN       NaN  31376      NaN    NaN
# 4512  ENSG00000209082   MT-TL1       NaN   7490      NaN    NaN
# 4513  ENSG00000210156    MT-TK       NaN   7489      NaN    NaN
# 4515  ENSG00000210107    MT-TQ       NaN   7495      NaN    NaN
# 4516  ENSG00000210176     TRNH       NaN   7487      NaN    NaN
# 4517  ENSG00000210151   MT-TS1       NaN   7497      NaN    NaN
# 4518  ENSG00000210184   MT-TS2       NaN   7498      NaN    NaN
# 4519  ENSG00000210049    MT-TF       NaN   7481      NaN    NaN
# 5155  ENSG00000281344      NaN       NaN  43984      NaN    NaN
# 5418              NaN      NaN       NaN    NaN      NaN    NaN
# 5521              NaN      NaN       NaN  22993      NaN    NaN
# 5713              NaN      NaN       NaN  25855      NaN    NaN
# 5716              NaN      NaN       NaN  14260      NaN    NaN
# 5719              NaN      NaN       NaN  16706      NaN    NaN
# 5720              NaN      NaN       NaN  13730      NaN    NaN
# 5843              NaN      NaN       NaN  30161      NaN    NaN
# 6111              NaN      NaN       NaN  20684      NaN    NaN
# 6112              NaN      NaN       NaN  17204      NaN    NaN
# 6294              NaN      NaN       NaN   8141      NaN    NaN
# 7340              NaN      NaN       NaN  43726      NaN    NaN
# 7548              NaN      NaN       NaN  32314      NaN    NaN

# %% [markdown]
# ## Example GO term similarity for two diseases

# %%
gard_gene_df[gard_gene_df['Gene_Symbol'].isin(gard_sym_go)].head()
# Out:
#    GARD_ID                     GARD_Disease  \
# 0        1                 GRACILE syndrome
# 1        3  Ablepharon macrostomia syndrome
# 3        5             Abetalipoproteinemia
# 5        7             Acromicric dysplasia
# 6        7             Acromicric dysplasia
#
#                   Disease_Gene_Association Gene_Symbol  \
# 0  Disease-causing germline mutation(s) in       BCS1L
# 1  Disease-causing germline mutation(s) in      TWIST2
# 3  Disease-causing germline mutation(s) in        MTTP
# 5  Disease-causing germline mutation(s) in        FBN1
# 6  Disease-causing germline mutation(s) in       LTBP3
#
#                                            Gene_Name  \
# 0  BCS1 homolog, ubiquinol-cytochrome c reductase...
# 1           twist family bHLH transcription factor 2
# 3           microsomal triglyceride transfer protein
# 5                                        fibrillin 1
# 6  latent transforming growth factor beta binding...
#
#                                            Gene_Refs    OMIM          Ensembl  \
# 0  [OMIM:603647, Ensembl:ENSG00000074582, Genatla...  603647  ENSG00000074582
# 1  [Ensembl:ENSG00000233608, OMIM:607556, Reactom...  607556  ENSG00000233608
# 3  [Ensembl:ENSG00000138823, Genatlas:MTTP, React...  157147  ENSG00000138823
# 5  [Reactome:P35555, Genatlas:FBN1, OMIM:134797, ...  134797  ENSG00000166147
# 6  [Reactome:Q9NS15, Genatlas:LTBP3, Ensembl:ENSG...  602090  ENSG00000168056
#
#   Genatlas SwissProt   HGNC Reactome IUPHAR
# 0    BCS1L    Q9Y276   1020   Q9Y276    NaN
# 1   TWIST2    Q8WVJ9  20670   Q8WVJ9    NaN
# 3     MTTP    P55157   7467   P55157    NaN
# 5     FBN1    P35555   3603   P35555    NaN
# 6    LTBP3    Q9NS15   6716   Q9NS15    NaN

# %%
go1 = gene2go['BCS1L']
go2 = gene2go['TWIST2']
print([go1['MF'],go2['MF']])
# Out:
# [[{'GO_ID': 'GO:0005515', 'Qualifier': {'enables'}}, {'GO_ID': 'GO:0005524', 'Qualifier': {'enables'}}], [{'GO_ID': 'GO:0005515', 'Qualifier': {'enables'}}, {'GO_ID': 'GO:0005515', 'Qualifier': {'enables'}}, {'GO_ID': 'GO:0005515', 'Qualifier': {'enables'}}, {'GO_ID': 'GO:0005515', 'Qualifier': {'enables'}}, {'GO_ID': 'GO:0005515', 'Qualifier': {'enables'}}, {'GO_ID': 'GO:0005515', 'Qualifier': {'enables'}}, {'GO_ID': 'GO:0005515', 'Qualifier': {'enables'}}, {'GO_ID': 'GO:0005515', 'Qualifier': {'enables'}}, {'GO_ID': 'GO:0005515', 'Qualifier': {'enables'}}, {'GO_ID': 'GO:0005515', 'Qualifier': {'enables'}}, {'GO_ID': 'GO:0005515', 'Qualifier': {'enables'}}, {'GO_ID': 'GO:0005515', 'Qualifier': {'enables'}}, {'GO_ID': 'GO:0005515', 'Qualifier': {'enables'}}, {'GO_ID': 'GO:0005515', 'Qualifier': {'enables'}}, {'GO_ID': 'GO:0005515', 'Qualifier': {'enables'}}, {'GO_ID': 'GO:0046983', 'Qualifier': {'enables'}}, {'GO_ID': 'GO:0000977', 'Qualifier': {'enables'}}, {'GO_ID': 'GO:0000981', 'Qualifier': {'enables'}}]]

# %%
go1['MF']
# Out:
# [{'GO_ID': 'GO:0005515', 'Qualifier': {'enables'}},
#  {'GO_ID': 'GO:0005524', 'Qualifier': {'enables'}}]

# %%
go2['MF']
# Out:
# [{'GO_ID': 'GO:0005515', 'Qualifier': {'enables'}},
#  {'GO_ID': 'GO:0005515', 'Qualifier': {'enables'}},
#  {'GO_ID': 'GO:0005515', 'Qualifier': {'enables'}},
#  {'GO_ID': 'GO:0005515', 'Qualifier': {'enables'}},
#  {'GO_ID': 'GO:0005515', 'Qualifier': {'enables'}},
#  {'GO_ID': 'GO:0005515', 'Qualifier': {'enables'}},
#  {'GO_ID': 'GO:0005515', 'Qualifier': {'enables'}},
#  {'GO_ID': 'GO:0005515', 'Qualifier': {'enables'}},
#  {'GO_ID': 'GO:0005515', 'Qualifier': {'enables'}},
#  {'GO_ID': 'GO:0005515', 'Qualifier': {'enables'}},
#  {'GO_ID': 'GO:0005515', 'Qualifier': {'enables'}},
#  {'GO_ID': 'GO:0005515', 'Qualifier': {'enables'}},
#  {'GO_ID': 'GO:0005515', 'Qualifier': {'enables'}},
#  {'GO_ID': 'GO:0005515', 'Qualifier': {'enables'}},
#  {'GO_ID': 'GO:0005515', 'Qualifier': {'enables'}},
#  {'GO_ID': 'GO:0046983', 'Qualifier': {'enables'}},
#  {'GO_ID': 'GO:0000977', 'Qualifier': {'enables'}},
#  {'GO_ID': 'GO:0000981', 'Qualifier': {'enables'}}]

# %%
similarity = gene_ontology.similarity('GO:0005515', 'GO:0046983', ic_metric="intrinsic_ic_sanchez")
# Access a single similarity metric
similarity.lin
# Access all similarity metrics
similarity.results()
# Out:
# {'node_0': 'GO:0005515',
#  'node_1': 'GO:0046983',
#  'node_0_subsumes_1': True,
#  'node_1_subsumes_0': False,
#  'n_common_ancestors': 3,
#  'n_union_ancestors': 4,
#  'batet': 0.75,
#  'batet_log': 1.0,
#  'ic_metric': 'intrinsic_ic_sanchez',
#  'mica': 'GO:0005515',
#  'resnik': 4.712053931186439,
#  'resnik_scaled': 0.46118000993019104,
#  'lin': 0.6488656392578207,
#  'jiang': 0.16393801599303162,
#  'jiang_seco': 0.7504319258465685}

# %% [markdown]
# # Disease - Phenotype

# %%
# Connect to disease ontology graph neo4j database
uri = "bolt://disease.ncats.io:80"
driver = GraphDatabase.driver(uri, auth=("neo4j", ""))

gard_phen_query = \
"""
MATCH r=(d:DATA)-[:PAYLOAD]->(n:S_GARD)-[:R_hasPhenotype]->(p:S_HP)<-[:PAYLOAD]-(z)
WHERE d.is_rare=true
RETURN DISTINCT d.id as `GARD_ID`, d.name as `GARD_Disease`,z.id as `HPO_ID`, z.label as `HPO_Phenotype`
ORDER BY d.id
"""

gard_phen_res = driver.session().run(gard_phen_query)

# %%
gard_phen_data = [dict(record) for record in gard_phen_res]
gard_phen_df = pd.DataFrame(gard_phen_data)

# %%
gard_phen_df
# Out:
#        GARD_ID                                       GARD_Disease      HPO_ID  \
# 0            1                                   GRACILE syndrome  HP:0100613
# 1            1                                   GRACILE syndrome  HP:0012465
# 2            1                                   GRACILE syndrome  HP:0012464
# 3            1                                   GRACILE syndrome  HP:0003128
# 4            1                                   GRACILE syndrome  HP:0003355
# ...        ...                                                ...         ...
# 93791    13818  Sphingosine phosphate lyase insufficiency synd...  HP:0000407
# 93792    13818  Sphingosine phosphate lyase insufficiency synd...  HP:0000252
# 93793    13818  Sphingosine phosphate lyase insufficiency synd...  HP:0001888
# 93794    13818  Sphingosine phosphate lyase insufficiency synd...  HP:0000007
# 93795    13818  Sphingosine phosphate lyase insufficiency synd...  HP:0009830
#
#                              HPO_Phenotype
# 0                 Death in early adulthood
# 1      Elevated hepatic iron concentration
# 2         Decreased transferrin saturation
# 3                          Lactic acidosis
# 4                            Aminoaciduria
# ...                                    ...
# 93791     Sensorineural hearing impairment
# 93792                         Microcephaly
# 93793                          Lymphopenia
# 93794      Autosomal recessive inheritance
# 93795                Peripheral neuropathy
#
# [93796 rows x 4 columns]

# %%
len(set(gard_phen_df.GARD_ID))
# Out:
# 3578

# %%
phenotype_ontology  = from_file("http://purl.obolibrary.org/obo/hp.obo")
# Out:
# /Users/sanjakjs/opt/anaconda3/envs/ontograph/lib/python3.8/site-packages/nxontology/imports.py:63: UnicodeWarning: unsound encoding, assuming ISO-8859-1 (73% confidence)
#   onto = Prontology(handle=handle)

# %%
similarity = phenotype_ontology.similarity('HP:0100613', 'HP:0003355', ic_metric="intrinsic_ic_sanchez")
# Access a single similarity metric
similarity.lin
# Access all similarity metrics
similarity.results()
# Out:
# {'node_0': 'HP:0100613',
#  'node_1': 'HP:0003355',
#  'node_0_subsumes_1': False,
#  'node_1_subsumes_0': False,
#  'n_common_ancestors': 1,
#  'n_union_ancestors': 15,
#  'batet': 0.06666666666666667,
#  'batet_log': 0.02547695440020664,
#  'ic_metric': 'intrinsic_ic_sanchez',
#  'mica': 'HP:0000001',
#  'resnik': 0.0,
#  'resnik_scaled': 0.0,
#  'lin': 0.0,
#  'jiang': 0.05706133276381606,
#  'jiang_seco': 0.11100666803057246}

# %% [markdown]
# ## Output

# %%
gard_phen_df.to_csv("data/gard2hpo.csv",index=False)

# %%
gard_gene_df.to_csv("data/gard2gene.csv",index=False)

# %%
import pickle

with open('data/gene2go.pickle', 'wb') as f:
    # Pickle the 'data' dictionary using the highest protocol available.
    pickle.dump(gene2go, f, pickle.HIGHEST_PROTOCOL)
